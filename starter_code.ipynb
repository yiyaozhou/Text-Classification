# %% [markdown]
# ## 情感分析项目

# %% [markdown]
# 本项目的目标是基于用户提供的评论，通过算法自动去判断其评论是正面的还是负面的情感。比如给定一个用户的评论：
# - 评论1： “我特别喜欢这个电器，我已经用了3个月，一点问题都没有！”
# - 评论2： “我从这家淘宝店卖的东西不到一周就开始坏掉了，强烈建议不要买，真实浪费钱”
#
# 对于这两个评论，第一个明显是正面的，第二个是负面的。 我们希望搭建一个AI算法能够自动帮我们识别出评论是正面还是负面。
#
# 情感分析的应用场景非常丰富，也是NLP技术在不同场景中落地的典范。比如对于一个证券领域，作为股民，其实比较关注舆论的变化，这个时候如果能有一个AI算法自动给网络上的舆论做正负面判断，然后把所有相关的结论再整合，这样我们可以根据这些大众的舆论，辅助做买卖的决策。 另外，在电商领域评论无处不在，而且评论已经成为影响用户购买决策的非常重要的因素，所以如果AI系统能够自动分析其情感，则后续可以做很多有意思的应用。

# %% [markdown]
# 情感分析是文本处理领域经典的问题。整个系统一般会包括几个模块：
# - 数据的抓取： 通过爬虫的技术去网络抓取相关文本数据
# - 数据的清洗/预处理：在本文中一般需要去掉无用的信息，比如各种标签（HTML标签），标点符号，停用词等等
# - 把文本信息转换成向量： 这也成为特征工程，文本本身是不能作为模型的输入，只有数字（比如向量）才能成为模型的输入。所以进入模型之前，任何的信号都需要转换成模型可识别的数字信号（数字，向量，矩阵，张量...)
# - 选择合适的模型以及合适的评估方法。 对于情感分析来说，这是二分类问题（或者三分类：正面，负面，中性），所以需要采用分类算法比如逻辑回归，朴素贝叶斯，神经网络，SVM等等。另外，我们需要选择合适的评估方法，比如对于一个应用，我们是关注准确率呢，还是关注召回率呢？

# %% [markdown]
# 在本次项目中，我们已经给定了训练数据和测试数据，它们分别是 ``train.positive.txt``, ``train.negative.txt``， ``test_combined.txt``. 请注意训练数据和测试数据的格式不一样，详情请见文件内容。 整个项目你需要完成以下步骤：
#
# 数据的读取以及清洗： 从给定的.txt中读取内容，并做一些数据清洗，这里需要做几个工作：
# - （1） 文本的读取，需要把字符串内容读进来。
# - （2）去掉无用的字符比如标点符号，多余的空格，换行符等
# - （3） 把文本转换成``TF-IDF``向量： 这部分直接可以利用sklearn提供的``TfidfVectorizer``类来做。
# - （4） 利用逻辑回归等模型来做分类，并通过交叉验证选择最合适的超参数
#
# 项目中需要用到的数据：
# - ``train.positive.txt``, ``train.negative.txt``， ``test_combined.txt``： 训练和测试数据
# - ``stopwords.txt``： 停用词库
#
#
# 你需要完成的部分为标记为`TODO`的部分。
#
# 另外，提交作业时候的注意点：
# > 1. 不要试图去创建另外一个.ipynb文件，所有的程序需要在`starter_code.ipynb`里面实现。很多的模块已经帮你写好，不要试图去修改已经定义好的函数以及名字。 当然，自己可以按需求来创建新的函数。但一定要按照给定的框架来写程序，不然判作业的时候会出现很多问题。
# > 2. 上传作业的时候把整个文件解压成.zip文件（不要.rar格式），请不要上传图片文件，其他的都需要上传包括`README.md`。
# > 3. 确保程序能够正常运行，我们支持的环境是`Python 3`,  千万不要使用`Python 2`
# > 4. 上传前一定要确保完整性，批改过一次的作业我们不会再重新批改，会作为最终的分数来对待。
# > 5. 作业可以讨论，但请自己完成。让我们一起遵守贪心学院的`honor code`。

# %% [markdown]
# ### 1. File Reading: 文本读取

# %%
import pandas as pd
import numpy as np
import os
from bs4 import BeautifulSoup

# %%
def read_txt_comments(file_name):
    # read the file
    file = open(file_name, mode = 'r')
    lines = file.read()
    file.close()
    # use bs4 parse data
    soup = BeautifulSoup(lines, 'html.parser')
    review = soup.findAll('review')
    review_list = []
    for i in range(len(review)):
        a_review = review[i].get_text().lstrip().rstrip().replace('\n', ' ')
        review_list.append(a_review)
    return review_list

# %%
def process_file(train_pos_file, train_neg_file, test_comb_file):  
    # TODO: 读取文件部分，把具体的内容写入到变量里面
    train_pos_comments = read_txt_comments(train_pos_file)
    train_neg_comments = read_txt_comments(train_neg_file)
    train_comments = train_pos_comments + train_neg_comments
    train_labels = [1]*len(train_pos_comments) + [0]*len(train_neg_comments)
    test_comments = read_txt_comments(test_comb_file)
    test_labels = []
    return train_pos_comments, train_neg_comments, train_comments, train_labels, test_comments, test_labels

# %%
train_pos_file = "train_positive.txt"
train_neg_file = "train_negative.txt"
test_comb_file = "test_combined.txt"

# %%
train_pos_comments, train_neg_comments, train_comments, train_labels, test_comments, test_labels = process_file(train_pos_file, train_neg_file, test_comb_file)

# %% [markdown]
# ### 2. Explorary Analysis: 做一些简单的可视化分析

# %%
# 训练数据和测试数据大小
print(len(train_comments), len(test_comments))
# Out:
# 8065 2500

# %% [markdown]
# > 这里有一个假设想验证。我觉得，如果一个评论是负面的，则用户留言时可能会长一些，因为对于负面的评论，用户很可能会把一些细节写得很清楚。但对于正面的评论，用户可能就只写“非常好”，这样的短句。我们想验证这个假设。 为了验证这个假设，打算画两个直方图，分别对正面的评论和负面的评论。 具体的做法是：1. 把正面和负面评论分别收集，之后分别对正面和负面评论画一个直方图。 2.  直方图的X轴是评论的长度，所以从是小到大的顺序。然后Y轴是对于每一个长度，出现了多少个正面或者负面的评论。 通过两个直方图的比较，即可以看出``评论``是否是一个靠谱的特征。

# %%
# TODO: 对于训练数据中的正负样本，分别画出一个histogram， histogram的x抽是每一个样本中字符串的长度，y轴是拥有这个长度的样本的百分比。
#       并说出样本长度是否对情感有相关性 (需要先用到结巴分词)
#       参考：https://baike.baidu.com/item/%E7%9B%B4%E6%96%B9%E5%9B%BE/1103834?fr=aladdin
#       画饼状图参考： https://pythonspot.com/matplotlib-histogram/   
#                   https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.hist.html
#!pip3 install jieba
import jieba

# %%
import plotly.graph_objects as go
import numpy as np

pos = [len(jieba.lcut(x)) for x in train_pos_comments]
neg = [len(jieba.lcut(x)) for x in train_neg_comments]

fig = go.Figure()
fig.add_trace(go.Histogram(x = pos, histnorm='probability', name = 'pos'))
fig.add_trace(go.Histogram(x = neg, histnorm='probability', name = 'neg'))

# Overlay both histograms
fig.update_layout(barmode='overlay')
# Reduce opacity to see both histograms
fig.update_traces(opacity=0.75)
fig.show()
# Out:
# <div>
#
#
#             <div id="26b507df-1830-4755-a0e5-43ab2d5b9dba" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("26b507df-1830-4755-a0e5-43ab2d5b9dba")) {
#                     Plotly.newPlot(
#                         '26b507df-1830-4755-a0e5-43ab2d5b9dba',
#                         [{"histnorm": "probability", "name": "pos", "opacity": 0.75, "type": "histogram", "x": [8, 24, 20, 5, 8, 9, 19, 6, 36, 4, 13, 40, 26, 16, 13, 42, 6, 23, 13, 18, 66, 9, 22, 5, 57, 10, 9, 12, 21, 21, 14, 23, 26, 12, 41, 58, 27, 16, 13, 21, 16, 3, 26, 20, 37, 20, 15, 4, 30, 13, 27, 44, 47, 74, 20, 49, 50, 10, 50, 33, 6, 22, 6, 56, 7, 3, 16, 31, 19, 6, 23, 25, 14, 4, 543, 38, 64, 7, 17, 15, 27, 28, 14, 4, 21, 13, 31, 18, 6, 16, 19, 5, 34, 18, 10, 7, 82, 34, 45, 118, 118, 27, 21, 30, 38, 9, 41, 9, 20, 24, 9, 55, 14, 26, 10, 4, 23, 62, 6, 101, 5, 30, 31, 13, 6, 9, 84, 23, 11, 18, 36, 44, 4, 23, 7, 11, 92, 64, 147, 18, 16, 4, 11, 15, 20, 16, 93, 25, 48, 35, 80, 100, 127, 7, 21, 69, 54, 19, 201, 48, 46, 26, 42, 7, 51, 9, 8, 55, 23, 11, 19, 23, 184, 14, 17, 13, 7, 11, 9, 5, 13, 5, 12, 39, 27, 20, 20, 16, 4, 327, 26, 63, 19, 23, 60, 4, 21, 11, 11, 12, 136, 2, 24, 24, 62, 8, 21, 41, 73, 12, 7, 12, 523, 28, 39, 16, 64, 12, 349, 35, 131, 34, 47, 4, 6, 10, 26, 21, 9, 96, 14, 10, 13, 206, 4, 307, 6, 3, 9, 7, 47, 27, 9, 36, 11, 16, 53, 12, 19, 26, 7, 18, 4, 6, 8, 29, 12, 12, 13, 2, 26, 10, 7, 6, 15, 30, 63, 13, 42, 24, 33, 24, 40, 30, 11, 10, 13, 36, 29, 7, 6, 41, 383, 18, 37, 23, 21, 62, 9, 59, 30, 11, 68, 18, 16, 63, 10, 13, 28, 5, 114, 37, 12, 11, 94, 11, 33, 31, 4, 6, 8, 22, 19, 67, 17, 40, 15, 7, 43, 14, 60, 58, 21, 14, 192, 81, 8, 16, 35, 18, 14, 26, 15, 316, 106, 9, 9, 13, 7, 6, 13, 7, 13, 11, 26, 74, 35, 6, 77, 7, 27, 15, 135, 4, 8, 20, 13, 58, 47, 19, 72, 24, 9, 22, 48, 6, 31, 15, 322, 11, 48, 134, 33, 8, 9, 83, 198, 30, 4, 36, 47, 6, 12, 39, 7, 113, 31, 58, 382, 28, 18, 4, 11, 9, 37, 44, 34, 2, 13, 6, 6, 15, 31, 40, 26, 11, 16, 6, 28, 31, 10, 13, 9, 38, 19, 128, 5, 27, 37, 130, 4, 64, 9, 23, 25, 12, 30, 15, 20, 30, 53, 43, 9, 59, 553, 49, 6, 62, 148, 7, 64, 6, 25, 46, 114, 3, 12, 40, 14, 7, 32, 20, 6, 3, 599, 20, 9, 25, 9, 6, 15, 48, 25, 45, 75, 48, 109, 12, 4, 28, 97, 24, 18, 8, 12, 131, 14, 25, 10, 23, 40, 5, 50, 21, 292, 15, 16, 49, 5, 13, 5, 5, 2, 6, 13, 12, 21, 17, 21, 35, 18, 40, 62, 545, 17, 15, 44, 34, 42, 14, 96, 43, 153, 14, 34, 11, 91, 15, 31, 32, 3, 9, 8, 102, 43, 14, 43, 100, 13, 30, 361, 25, 122, 6, 4, 7, 28, 11, 4, 17, 13, 28, 5, 25, 86, 12, 17, 74, 4, 21, 22, 86, 34, 11, 25, 57, 7, 11, 37, 12, 16, 323, 91, 65, 58, 35, 40, 9, 28, 20, 49, 32, 25, 329, 32, 2, 27, 5, 12, 22, 20, 15, 41, 15, 94, 82, 189, 21, 20, 15, 4, 6, 2, 15, 29, 24, 35, 9, 33, 14, 17, 13, 11, 4, 7, 133, 4, 11, 20, 70, 31, 14, 4, 69, 7, 3, 6, 64, 538, 17, 16, 57, 36, 16, 5, 42, 3, 32, 30, 19, 7, 17, 35, 23, 27, 11, 4, 71, 5, 26, 44, 84, 8, 21, 26, 18, 6, 68, 5, 4, 59, 6, 22, 13, 6, 13, 25, 24, 5, 6, 21, 137, 14, 4, 36, 23, 3, 15, 14, 13, 48, 10, 102, 17, 16, 38, 421, 5, 8, 50, 16, 22, 8, 25, 36, 16, 25, 12, 462, 3, 9, 6, 19, 94, 13, 9, 4, 12, 9, 10, 7, 67, 4, 7, 22, 18, 25, 10, 18, 19, 9, 15, 98, 15, 64, 22, 9, 4, 20, 30, 14, 5, 11, 45, 8, 2, 28, 77, 4, 30, 13, 13, 31, 41, 7, 370, 201, 50, 48, 2, 10, 53, 8, 16, 22, 12, 8, 38, 16, 16, 13, 21, 8, 25, 14, 51, 25, 236, 19, 3, 62, 19, 26, 14, 42, 30, 288, 6, 13, 47, 11, 28, 190, 71, 69, 38, 19, 7, 27, 3, 11, 15, 5, 8, 26, 21, 26, 40, 6, 72, 7, 58, 9, 3, 44, 31, 10, 6, 21, 2, 6, 7, 3, 17, 5, 55, 65, 25, 4, 35, 19, 20, 26, 28, 32, 45, 633, 12, 107, 502, 3, 3, 8, 4, 77, 25, 80, 7, 50, 6, 12, 10, 88, 16, 14, 13, 53, 41, 14, 20, 46, 5, 27, 47, 172, 18, 29, 46, 19, 25, 18, 8, 22, 3, 28, 23, 13, 43, 7, 95, 6, 11, 6, 123, 34, 9, 223, 17, 13, 21, 8, 8, 33, 17, 29, 613, 35, 7, 13, 90, 97, 23, 81, 20, 34, 20, 9, 1, 144, 115, 17, 31, 25, 16, 7, 9, 77, 6, 12, 67, 17, 17, 14, 3, 1, 17, 20, 25, 10, 10, 22, 65, 31, 22, 87, 8, 10, 23, 43, 3, 41, 11, 29, 18, 19, 8, 356, 9, 6, 19, 24, 329, 3, 22, 60, 20, 36, 235, 15, 6, 222, 13, 15, 20, 35, 4, 16, 17, 48, 3, 23, 23, 27, 32, 7, 17, 9, 19, 16, 3, 38, 6, 5, 6, 467, 4, 16, 10, 16, 180, 47, 9, 4, 62, 17, 15, 43, 28, 11, 17, 50, 29, 18, 5, 18, 12, 3, 12, 35, 5, 8, 7, 6, 32, 19, 25, 35, 99, 18, 31, 367, 42, 8, 9, 42, 3, 47, 32, 25, 9, 18, 22, 62, 25, 12, 18,  ...

# %%
from scipy.stats import ks_2samp
ks_2samp(pos, neg)
# Out:
# Ks_2sampResult(statistic=0.0975399673735726, pvalue=1.0)

# %% [markdown]
# // TODO: 情感跟评论长度是否有相关性？
#
# // From the histogram, positive comments have a larger proportion of "<25 words comments", compared with the negative comments. But from the KS test result, the difference is not significant.

# %% [markdown]
# ### 3. 文本预处理
# > 在此部分需要做文本预处理方面的工作。 分为几大块：
# - ``去掉特殊符号``  比如#$.... 这部分的代码已经给出，不需要自己写
# - ``把数字转换成特殊单词`` 把数字转换成 " NUM "， 这部分需要写。 注意：NUM前面和后面加一个空格，这样可以保证之后分词时被分掉。
# - ``分词并过滤掉停用词`` 停用词库已经提供，需要读取停用词库，并按照此停用词库做过滤。 停用词库使用给定的文件：``stopwords.txt``

# %%
file = open('stopwords.txt', mode = 'r')
stop_words = file.read()
file.close()

# %%
stop_words = list(stop_words)
# Out:
# ['—',
#  '—',
#  '—',
#  '\n',
#  '》',
#  '）',
#  '，',
#  '\n',
#  '）',
#  '÷',
#  '（',
#  '１',
#  '－',
#  '\n',
#  '”',
#  '，',
#  '\n',
#  '）',
#  '、',
#  '\n',
#  '＝',
#  '（',
#  '\n',
#  ':',
#  '\n',
#  '→',
#  '\n',
#  '℃',
#  ' ',
#  '\n',
#  '&',
#  '\n',
#  '*',
#  '\n',
#  '一',
#  '一',
#  '\n',
#  '~',
#  '~',
#  '~',
#  '~',
#  '\n',
#  '’',
#  '\n',
#  '.',
#  ' ',
#  '\n',
#  '『',
#  '\n',
#  '.',
#  '一',
#  '\n',
#  '.',
#  '/',
#  '\n',
#  '-',
#  '-',
#  ' ',
#  '\n',
#  '』',
#  '\n',
#  '＝',
#  '″',
#  '\n',
#  '【',
#  '\n',
#  '［',
#  '＊',
#  '］',
#  '\n',
#  '｝',
#  '＞',
#  '\n',
#  '［',
#  '⑤',
#  '］',
#  '］',
#  '\n',
#  '［',
#  '①',
#  'Ｄ',
#  '］',
#  '\n',
#  'ｃ',
#  '］',
#  '\n',
#  'ｎ',
#  'ｇ',
#  '昉',
#  '\n',
#  '＊',
#  '\n',
#  '/',
#  '/',
#  '\n',
#  '［',
#  '\n',
#  '］',
#  '\n',
#  '［',
#  '②',
#  'ｅ',
#  '］',
#  '\n',
#  '［',
#  '②',
#  'ｇ',
#  '］',
#  '\n',
#  '＝',
#  '｛',
#  '\n',
#  '}',
#  '\n',
#  '，',
#  '也',
#  ' ',
#  '\n',
#  '‘',
#  '\n',
#  'Ａ',
#  '\n',
#  '［',
#  '①',
#  '⑥',
#  '］',
#  '\n',
#  '［',
#  '②',
#  'Ｂ',
#  '］',
#  ' ',
#  '\n',
#  '［',
#  '①',
#  'ａ',
#  '］',
#  '\n',
#  '［',
#  '④',
#  'ａ',
#  '］',
#  '\n',
#  '［',
#  '①',
#  '③',
#  '］',
#  '\n',
#  '［',
#  '③',
#  'ｈ',
#  '］',
#  '\n',
#  '③',
#  '］',
#  '\n',
#  '１',
#  '．',
#  ' ',
#  '\n',
#  '－',
#  '－',
#  ' ',
#  '\n',
#  '［',
#  '②',
#  'ｂ',
#  '］',
#  '\n',
#  '’',
#  '‘',
#  ' ',
#  '\n',
#  '×',
#  '×',
#  '×',
#  ' ',
#  '\n',
#  '［',
#  '①',
#  '⑧',
#  '］',
#  '\n',
#  '０',
#  '：',
#  '２',
#  ' ',
#  '\n',
#  '＝',
#  '［',
#  '\n',
#  '［',
#  '⑤',
#  'ｂ',
#  '］',
#  '\n',
#  '［',
#  '②',
#  'ｃ',
#  '］',
#  ' ',
#  '\n',
#  '［',
#  '④',
#  'ｂ',
#  '］',
#  '\n',
#  '［',
#  '②',
#  '③',
#  '］',
#  '\n',
#  '［',
#  '③',
#  'ａ',
#  '］',
#  '\n',
#  '［',
#  '④',
#  'ｃ',
#  '］',
#  '\n',
#  '［',
#  '①',
#  '⑤',
#  '］',
#  '\n',
#  '［',
#  '①',
#  '⑦',
#  '］',
#  '\n',
#  '［',
#  '①',
#  'ｇ',
#  '］',
#  '\n',
#  '∈',
#  '［',
#  ' ',
#  '\n',
#  '［',
#  '①',
#  '⑨',
#  '］',
#  '\n',
#  '［',
#  '①',
#  '④',
#  '］',
#  '\n',
#  '［',
#  '①',
#  'ｃ',
#  '］',
#  '\n',
#  '［',
#  '②',
#  'ｆ',
#  '］',
#  '\n',
#  '［',
#  '②',
#  '⑧',
#  '］',
#  '\n',
#  '［',
#  '②',
#  '①',
#  '］',
#  '\n',
#  '［',
#  '①',
#  'Ｃ',
#  '］',
#  '\n',
#  '［',
#  '③',
#  'ｃ',
#  '］',
#  '\n',
#  '［',
#  '③',
#  'ｇ',
#  '］',
#  '\n',
#  '［',
#  '②',
#  '⑤',
#  '］',
#  '\n',
#  '［',
#  '②',
#  '②',
#  '］',
#  '\n',
#  '一',
#  '.',
#  '\n',
#  '［',
#  '①',
#  'ｈ',
#  '］',
#  '\n',
#  '.',
#  '数',
#  '\n',
#  '［',
#  '］',
#  '\n',
#  '［',
#  '①',
#  'Ｂ',
#  '］',
#  '\n',
#  '数',
#  '/',
#  '\n',
#  '［',
#  '①',
#  'ｉ',
#  '］',
#  '\n',
#  '［',
#  '③',
#  'ｅ',
#  '］',
#  '\n',
#  '［',
#  '①',
#  '①',
#  '］',
#  '\n',
#  '［',
#  '④',
#  'ｄ',
#  '］',
#  '\n',
#  '［',
#  '④',
#  'ｅ',
#  '］',
#  '\n',
#  '［',
#  '③',
#  'ｂ',
#  '］',
#  '\n',
#  '［',
#  '⑤',
#  'ａ',
#  '］',
#  '\n',
#  '［',
#  '①',
#  'Ａ',
#  '］',
#  '\n',
#  '［',
#  '②',
#  '⑧',
#  '］',
#  '\n',
#  '［',
#  '②',
#  '⑦',
#  '］',
#  '\n',
#  '［',
#  '①',
#  'ｄ',
#  '］',
#  '\n',
#  '［',
#  '②',
#  'ｊ',
#  '］',
#  '\n',
#  '〕',
#  '〔',
#  '\n',
#  '］',
#  '［',
#  '\n',
#  ':',
#  '/',
#  '/',
#  '\n',
#  '′',
#  '∈',
#  '\n',
#  '［',
#  '②',
#  '④',
#  '\n',
#  '［',
#  '⑤',
#  'ｅ',
#  '］',
#  '\n',
#  '１',
#  '２',
#  '％',
#  '\n',
#  'ｂ',
#  '］',
#  '\n',
#  '.',
#  '.',
#  '.',
#  '\n',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '\n',
#  '…',
#  '…',
#  '…',
#  '…',
#  '…',
#  '…',
#  '…',
#  '…',
#  '…',
#  '…',
#  '…',
#  '…',
#  '…',
#  '…',
#  '…',
#  '…',
#  '…',
#  '…',
#  '…',
#  '③',
#  '\n',
#  'Ｚ',
#  'Ｘ',
#  'Ｆ',
#  'Ｉ',
#  'Ｔ',
#  'Ｌ',
#  '\n',
#  '［',
#  '③',
#  'Ｆ',
#  '］',
#  '\n',
#  '」',
#  '\n',
#  '［',
#  '①',
#  'ｏ',
#  '］',
#  '\n',
#  '］',
#  '∧',
#  '′',
#  '＝',
#  '［',
#  ' ',
#  '\n',
#  '∪',
#  'φ',
#  '∈',
#  '\n',
#  '′',
#  '｜',
#  '\n',
#  '｛',
#  '－',
#  '\n',
#  '②',
#  'ｃ',
#  '\n',
#  '｝',
#  '\n',
#  '［',
#  '③',
#  '①',
#  '］',
#  '\n',
#  'Ｒ',
#  '．',
#  'Ｌ',
#  '．',
#  '\n',
#  '［',
#  '①',
#  'Ｅ',
#  '］',
#  '\n',
#  'Ψ',
#  '\n',
#  '－',
#  '［',
#  '＊',
#  '］',
#  '－',
#  '\n',
#  '↑',
#  '\n',
#  '.',
#  '日',
#  ' ',
#  '\n',
#  '［',
#  '②',
#  'ｄ',
#  '］',
#  '\n',
#  '［',
#  '②',
#  '\n',
#  '［',
#  '②',
#  '⑦',
#  '］',
#  '\n',
#  '［',
#  '②',
#  '②',
#  '］',
#  '\n',
#  '［',
#  '③',
#  'ｅ',
#  '］',
#  '\n',
#  '［',
#  '①',
#  'ｉ',
#  '］',
#  '\n',
#  '［',
#  '①',
#  'Ｂ',
#  '］',
#  '\n',
#  '［',
#  '①',
#  'ｈ',
#  '］',
#  '\n',
#  '［',
#  '①',
#  'ｄ',
#  '］',
#  '\n',
#  '［',
#  '①',
#  'ｇ',
#  '］',
#  '\n',
#  '［',
#  '①',
#  '②',
#  '］',
#  '\n',
#  '［',
#  '②',
#  'ａ',
#  '］',
#  '\n',
#  'ｆ',
#  '］',
#  '\n',
#  '［',
#  '⑩',
#  '］',
#  '\n',
#  'ａ',
#  '］',
#  '\n',
#  '［',
#  '①',
#  'ｅ',
#  '］',
#  '\n',
#  '［',
#  '②',
#  'ｈ',
#  '］',
#  '\n',
#  '［',
#  '②',
#  '⑥',
#  '］',
#  '\n',
#  '［',
#  '③',
#  'ｄ',
#  '］',
#  '\n',
#  '［',
#  '②',
#  '⑩',
#  '］',
#  '\n',
#  'ｅ',
#  '］',
#  '\n',
#  '〉',
#  '\n',
#  '】',
#  '\n',
#  '元',
#  '／',
#  '吨',
#  '\n',
#  '［',
#  '②',
#  '⑩',
#  '］',
#  '\n',
#  '２',
#  '．',
#  '３',
#  '％',
#  '\n',
#  '５',
#  '：',
#  '０',
#  ' ',
#  ' ',
#  '\n',
#  '［',
#  '①',
#  '］',
#  '\n',
#  ':',
#  ':',
#  '\n',
#  '［',
#  '②',
#  '］',
#  '\n',
#  '［',
#  '③',
#  '］',
#  '\n',
#  '［',
#  '④',
#  '］',
#  '\n',
#  '［',
#  '⑤',
#  '］',
#  '\n',
#  '［',
#  '⑥',
#  '］',
#  '\n',
#  '［',
#  '⑦',
#  '］',
#  '\n',
#  '［',
#  '⑧',
#  '］',
#  '\n',
#  '［',
#  '⑨',
#  '］',
#  ' ',
#  '\n',
#  '…',
#  '…',
#  '\n',
#  '—',
#  '—',
#  '\n',
#  '?',
#  '\n',
#  '、',
#  '\n',
#  '。',
#  '\n',
#  '“',
#  '\n',
#  '”',
#  '\n',
#  '《',
#  '\n',
#  '》',
#  '\n',
#  '！',
#  '\n',
#  '，',
#  '\n',
#  '：',
#  '\n',
#  '；',
#  '\n',
#  '？',
#  '\n',
#  '．',
#  '\n',
#  ',',
#  '\n',
#  '．',
#  '\n',
#  "'",
#  '\n',
#  '?',
#  ' ',
#  '\n',
#  '·',
#  '\n',
#  '—',
#  '—',
#  '—',
#  '\n',
#  '─',
#  '─',
#  '\n',
#  '?',
#  ' ',
#  '\n',
#  '—',
#  '\n',
#  '<',
#  '\n',
#  '>',
#  '\n',
#  '（',
#  '\n',
#  '）',
#  '\n',
#  '〔',
#  '\n',
#  '〕',
#  '\n',
#  '[',
#  '\n',
#  ']',
#  '\n',
#  '(',
#  '\n',
#  ')',
#  '\n',
#  '-',
#  '\n',
#  '+',
#  '\n',
#  '～',
#  '\n',
#  '×',
#  '\n',
#  '／',
#  '\n',
#  '/',
#  '\n',
#  '①',
#  '\n',
#  '②',
#  '\n',
#  '③',
#  '\n',
#  '④',
#  '\n',
#  '⑤',
#  '\n',
#  '⑥',
#  '\n',
#  '⑦',
#  '\n',
#  '⑧',
#  '\n',
#  '⑨',
#  '\n',
#  '⑩',
#  '\n',
#  'Ⅲ',
#  '\n',
#  'В',
#  '\n',
#  '"',
#  '\n',
#  ';',
#  '\n',
#  '#',
#  '\n',
#  '@',
#  '\n',
#  'γ',
#  '\n',
#  'μ',
#  '\n',
#  'φ',
#  '\n',
#  'φ',
#  '．',
#  '\n',
#  '×',
#  ' ',
#  '\n',
#  'Δ',
#  '\n',
#  '■',
#  '\n',
#  '▲',
#  '\n',
#  's',
#  'u',
#  'b',
#  '\n',
#  'e',
#  'x',
#  'p',
#  ' ',
#  '\n',
#  's',
#  'u',
#  'p',
#  '\n',
#  's',
#  'u',
#  'b',
#  '\n',
#  'L',
#  'e',
#  'x',
#  ' ',
#  '\n',
#  '＃',
#  '\n',
#  '％',
#  '\n',
#  '＆',
#  '\n',
#  '＇',
#  '\n',
#  '＋',
#  '\n',
#  '＋',
#  'ξ',
#  '\n',
#  '＋',
#  '＋',
#  '\n',
#  '－',
#  '\n',
#  '－',
#  'β',
#  '\n',
#  '＜',
#  '\n',
#  '＜',
#  '±',
#  '\n',
#  '＜',
#  'Δ',
#  '\n',
#  '＜',
#  'λ',
#  '\n',
#  '＜',
#  'φ',
#  '\n',
#  '＜',
#  '＜',
#  '\n',
#  '=',
#  '\n',
#  '＝',
#  '\n',
#  '＝',
#  '☆',
#  '\n',
#  '＝',
#  '－',
#  '\n',
#  '＞',
#  '\n',
#  '＞',
#  'λ',
#  '\n',
#  '＿',
#  '\n',
#  '～',
#  '±',
#  '\n',
#  '～',
#  '＋',
#  '\n',
#  '［',
#  '⑤',
#  'ｆ',
#  '］',
#  '\n',
#  '［',
#  '⑤',
#  'ｄ',
#  '］',
#  '\n',
#  '［',
#  '②',
#  'ｉ',
#  '］',
#  '\n',
#  '≈',
#  ' ',
#  '\n',
#  '［',
#  '②',
#  'Ｇ',
#  '］',
#  '\n',
#  '［',
#  '①',
#  'ｆ',
#  '］',
#  '\n',
#  'Ｌ',
#  'Ｉ',
#  '\n',
#  '㈧',
#  ' ',
#  '\n',
#  '［',
#  '－',
#  '\n',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '\n',
#  '〉',
#  '\n',
#  '［',
#  '③',
#  '⑩',
#  '］',
#  '\n',
#  '第',
#  '二',
#  '\n',
#  '一',
#  '番',
#  '\n',
#  '一',
#  '直',
#  '\n',
#  '一',
#  '个',
#  '\n',
#  '一',
#  '些',
#  '\n',
#  '许',
#  '多',
#  '\n',
#  '种',
#  '\n',
#  '有',
#  '的',
#  '是',
#  '\n',
#  '也',
#  '就',
#  '是',
#  '说',
#  '\n',
#  '末',
#  '#',
#  '#',
#  '末',
#  '\n',
#  '啊',
#  '\n',
#  '阿',
#  '\n',
#  '哎',
#  '\n',
#  '哎',
#  '呀',
#  '\n',
#  '哎',
#  '哟',
#  '\n',
#  '唉',
#  ...]

# %%
import re
def clean_nums_symbols(text):
    """
    对特殊符号做一些处理，此部分已写好。如果不满意也可以自行改写，不记录分数。
    """
    text = re.sub(r'\d+[\d.]*', 'NUM', text)
    text = re.sub('[!！]+', "!", text)
    text = re.sub('[?？]+', "?", text)
    text = re.sub("[a-zA-Z#$%&\'()*+,-./:;：<=>@，。★、…【】《》“”‘’[\\]^_`{|}~～]+ó", " OOV ", text)
    return re.sub("\s+", " ", text)  

def clean_nums_symbols_list(comments_list):
    clean_comments_list = []
    for text in comments_list:
        clean_comments_list.append(clean_nums_symbols(text))
    return clean_comments_list

def remove_stop_words(clean_comments_list):
    list_tokens = [jieba.lcut(x) for x in clean_nums_symbols_list(clean_comments_list)]
    clean_list_tokens = []
    for tokens in list_tokens:    
        clean_tokens = tokens[:]
        for token in tokens:
            if token in stop_words:
                clean_tokens.remove(token)
        clean_list_tokens.append(clean_tokens)
    return clean_list_tokens

# TODO：对于train_comments, test_comments进行字符串的处理，几个考虑的点：
#   1. 去掉特殊符号
#   2. 把数字转换成特殊字符或者单词
#   3. 分词并做停用词过滤
#   4. ... （或者其他）
#
#   需要注意的点是，由于评论数据本身很短，如果去掉的太多，很可能字符串长度变成0
#   预处理部分，可以自行选择合适的方.

train_comments_cleaned = [] 
test_comments_cleaned = []

# %%
clean_train_comments = clean_nums_symbols_list(train_comments)

# %%
remove_stop_words(clean_comments_list)
# Out:
# [['请问', '这机', '有个', '遥控器'],
#  ['发短信',
#   '特别',
#   '方便',
#   '!',
#   '背后',
#   '屏幕',
#   '很大',
#   '起来',
#   '舒服',
#   'OOV',
#   '手触',
#   '屏',
#   '!',
#   '切换',
#   '屏幕',
#   '很',
#   '麻烦',
#   '!'],
#  ['手感',
#   '超好',
#   'OOV',
#   '黑色',
#   '相比',
#   '白色',
#   '转得',
#   '容易',
#   '眼花',
#   'OOV',
#   '找',
#   '童年',
#   '记忆',
#   'OOV'],
#  ['!'],
#  ['付款', '信用'],
#  ['价格', '质量', '售后', '都', '很', '满意'],
#  ['书',
#   '质量',
#   '印刷',
#   '都',
#   '不错',
#   'OOV',
#   '字',
#   '大小',
#   '刚刚',
#   'OOV',
#   '很',
#   '清楚',
#   'OOV',
#   '喜欢'],
#  ['超级', '值得', '电影'],
#  ['今天',
#   '突然',
#   '看到',
#   '卓越',
#   '卖',
#   'OOV',
#   '韩国',
#   '卖',
#   '没有',
#   'OOV',
#   '引进',
#   '版',
#   'OOV',
#   '之前',
#   '卖',
#   '没有',
#   'OOV',
#   '卓越',
#   '哪里找',
#   '出来'],
#  ['江大', 'OOV', '继续', '写'],
#  ['不错', 'OOV', '跟着', '练', '才能', 'OOV'],
#  ['前天',
#   '两本',
#   '一起',
#   '买',
#   'OOV',
#   'OOV',
#   '一下子',
#   '降价',
#   'OOV',
#   '但书',
#   '很大',
#   '帮助',
#   'OOV',
#   '发货',
#   '速度',
#   '很快',
#   'OOV',
#   '隔天',
#   'OOV',
#   '!'],
#  ['内容',
#   '不必',
#   '细说',
#   'OOV',
#   '都',
#   '知道',
#   'OOV',
#   '质量',
#   '比较',
#   'OOV',
#   '尽善尽美',
#   'OOV',
#   '企事业',
#   '算是',
#   '不错',
#   'OOV'],
#  ['OOV', '本书', '相信', '真有', '时间', '隧道', 'OOV'],
#  ['发货', '迅速', 'OOV', '书', '质量', '很', 'OOV', '很', '满意', 'OOV'],
#  ['一本',
#   '指导',
#   '性质',
#   '编程',
#   '类书籍',
#   'OOV',
#   '本书',
#   '设计模式',
#   '演绎',
#   '淋漓尽致',
#   'OOV',
#   '通俗易懂',
#   'OOV',
#   '看后',
#   '获益匪浅',
#   '!',
#   '设计模式',
#   'OOV',
#   '真正',
#   'OOV',
#   '需要',
#   '实际',
#   '磨练',
#   'OOV'],
#  ['绝对', '容错过', '收藏', '!'],
#  ['出售',
#   '购买',
#   '盗版',
#   '都',
#   '违法行为',
#   'OOV',
#   '还敢',
#   '随便',
#   '瞎',
#   '起哄',
#   'OOV',
#   '想想',
#   '像是'],
#  ['知道', '拨号', '数字', '大不大', 'OOV', '话筒', '音量', '大不大', 'OOV'],
#  ['神秘园', '曲子', '总是', '打动', '心中', '最', '真的', '地方', 'OOV', '太', '好听', 'OOV'],
#  ['上次',
#   '买',
#   '五月天',
#   '专辑',
#   '几本书',
#   'OOV',
#   '特别',
#   '说明',
#   '包装',
#   '牢固',
#   'OOV',
#   '箱子',
#   'OOV',
#   '很',
#   '感动',
#   'OOV',
#   '这次',
#   'OOV',
#   '几本书',
#   'OOV',
#   '包装',
#   '特别',
#   '说明',
#   'OOV',
#   '竟然',
#   '胶带',
#   'OOV',
#   '气死我了',
#   '!',
#   '还好',
#   'OOV',
#   '没有',
#   '破损',
#   'OOV',
#   '对不起',
#   '布兰妮',
#   '!',
#   'OOV',
#   '服务',
#   '每况愈下'],
#  ['挺', '!', '有空', '去', '听听', '!'],
#  ['鸟哥', '鸟哥', 'OOV', '书', 'OOV', '初学者', '很', '帮助', 'OOV', '可惜', '少有', '时间'],
#  ['发货', '很', '即时', 'OOV', '很快'],
#  ['第一眼',
#   '看到',
#   '款',
#   '手机',
#   '太',
#   '喜欢',
#   'OOV',
#   '价格',
#   '不贵',
#   'OOV',
#   '朋友',
#   '很多',
#   '都',
#   '买',
#   '新手机',
#   'OOV',
#   '想',
#   '买',
#   'OOV',
#   '现在',
#   '手机',
#   '好好',
#   'OOV',
#   '真的',
#   '很',
#   '想要',
#   'OOV',
#   '没',
#   '办法',
#   'OOV',
#   '继续',
#   '关注',
#   '!'],
#  ['非常', '不错', '一部', '歌舞', '电影', '!', '很', '青春', '!'],
#  ['四天', '左右', '货', 'OOV', '书', '很', '整洁'],
#  ['起来', '很', '不错', 'OOV', '没有', '出现', '问题', 'OOV', '价格', '不贵'],
#  ['挺不错', 'OOV', '老狼', '没有', '变化', 'OOV', '听', '歌', '永远', '想起', '纯真', '年代'],
#  ['结合', '电影', '教学', 'OOV', '碰到', '喜欢', '电影', 'OOV', '效率', '高', '!'],
#  ['不错', '本书', 'OOV', '很', '实用', 'OOV', '继续', '购买', '系列'],
#  ['游戏',
#   '品质',
#   '不用',
#   '希望',
#   '星空',
#   '顶住',
#   'OOV',
#   '以后',
#   '带给',
#   '更',
#   '精彩',
#   '欧美',
#   '奇幻',
#   '游戏'],
#  ['风扇',
#   '质量',
#   '不错',
#   'OOV',
#   '有点',
#   '吵',
#   '!',
#   '呵呵',
#   'OOV',
#   '前面',
#   '转扇',
#   '壳子',
#   '拆',
#   'OOV',
#   '现在',
#   '安静',
#   'OOV',
#   '静音',
#   '!'],
#  ['都', '哥们', '有点', '极端', '!', '觉得', '这才', '爱憎分明', '!'],
#  ['时间',
#   '有货',
#   '我订',
#   'OOV',
#   '还订',
#   '洗发',
#   '用品',
#   'OOV',
#   '送来',
#   '洗发',
#   '洒',
#   '一半',
#   'OOV',
#   '只能',
#   '全部',
#   '退回',
#   'OOV',
#   '时间',
#   '货',
#   'OOV',
#   '我要',
#   '订购',
#   '!'],
#  ['OOV',
#   '营销',
#   'OOV',
#   '本书',
#   '确实',
#   '不错',
#   'OOV',
#   '作者',
#   '亲身',
#   '实例',
#   '解读',
#   '营销',
#   '这一',
#   '过程',
#   'OOV',
#   '书中',
#   '讲解',
#   '通俗易懂',
#   'OOV',
#   '践行',
#   '起来',
#   '很',
#   '困难',
#   'OOV',
#   '哪位',
#   '营销',
#   '人员',
#   '能够',
#   '完全',
#   '复制',
#   '乔',
#   'OOV',
#   '吉拉德',
#   '成功',
#   '经历',
#   'OOV',
#   '取得',
#   '乔',
#   '成功',
#   'OOV'],
#  ['很',
#   '喜欢',
#   'OOV',
#   'OOV',
#   'OOV',
#   '已经',
#   '买',
#   '两部',
#   '牒',
#   'OOV',
#   'OOV',
#   '部到',
#   '现在',
#   '没有',
#   '!'],
#  ['降价', 'OOV', '等待'],
#  ['自动',
#   '查杀',
#   '病毒',
#   'OOV',
#   '资源',
#   '占用',
#   '小',
#   'OOV',
#   '内存',
#   '占用率',
#   '比较',
#   '低',
#   'OOV'],
#  ['听',
#   'OOV',
#   '美梦成真',
#   'OOV',
#   '泪海',
#   'OOV',
#   '喜欢',
#   'OOV',
#   '好像',
#   '蛮',
#   '长时间',
#   '没',
#   '新歌',
#   'OOV'],
#  ['痘',
#   '印上',
#   'OOV',
#   '都',
#   '看不出来',
#   'OOV',
#   '很',
#   '不错',
#   'OOV',
#   '支持',
#   '一下',
#   '!',
#   'OOV'],
#  ['很', '喜欢'],
#  ['惠兰',
#   '这套',
#   '很',
#   '适合',
#   '家里',
#   '练',
#   'OOV',
#   '本想',
#   '报个',
#   '瑜伽',
#   '班',
#   'OOV',
#   '这下',
#   '可省',
#   '几大百',
#   'OOV',
#   '电视',
#   '效果',
#   '很',
#   '清楚',
#   'OOV'],
#  ['质量',
#   '行',
#   'OOV',
#   '喜欢',
#   '张',
#   '帅哥',
#   '作品',
#   'OOV',
#   '有点',
#   '贵',
#   'OOV',
#   '我认',
#   'OOV'],
#  ['OOV',
#   '指环王',
#   'OOV',
#   '三部曲',
#   '电影',
#   '音乐',
#   '大气',
#   'OOV',
#   '细腻',
#   'OOV',
#   '交响乐',
#   '般的',
#   'OOV',
#   '旋律',
#   '性',
#   '很',
#   '强',
#   'OOV',
#   '非常',
#   '好听',
#   'OOV',
#   '值得',
#   '收藏',
#   'OOV',
#   '这套',
#   '碟片',
#   '音质',
#   '欠缺',
#   'OOV'],
#  ['很',
#   '激动',
#   'OOV',
#   '强大',
#   '品牌',
#   '之道',
#   'OOV',
#   '实现',
#   'OOV',
#   '这才',
#   '价值',
#   '所在',
#   'OOV'],
#  ['图像',
#   '清晰',
#   'OOV',
#   '配音',
#   '清楚',
#   'OOV',
#   '价格比',
#   '盗版',
#   '都',
#   '低',
#   'OOV',
#   '值得',
#   '收藏',
#   '!'],
#  ['不错', '实用'],
#  ['最后',
#   '一本',
#   'OOV',
#   '拜托',
#   '卓越',
#   '一定',
#   '想',
#   '办法',
#   'OOV',
#   '让霆锋',
#   '签次',
#   '名',
#   '!',
#   '拜托',
#   '拜托',
#   'OOV',
#   '!'],
#  ['希望', '以后', '马先生', '讲得', '内容', '应', '卓越', '买'],
#  ['听',
#   '蛮',
#   '经典',
#   'OOV',
#   'OOV',
#   '想象',
#   '大',
#   'OOV',
#   '没',
#   '想象',
#   '做工',
#   'OOV',
#   '毕竟',
#   '大',
#   '牌子',
#   'OOV'],
#  ['很',
#   '喜欢',
#   '英雄无敌',
#   '系列',
#   '游戏',
#   'OOV',
#   '历代',
#   '英雄无敌',
#   '系列',
#   '都',
#   '玩',
#   'OOV',
#   '更',
#   '不能',
#   '放过',
#   '英雄无敌',
#   '五',
#   'OOV',
#   '正版',
#   '游戏',
#   '质量',
#   '保证',
#   'OOV',
#   '卓越',
#   '现在',
#   '价格',
#   '很',
#   '超值',
#   'OOV',
#   '买',
#   '一套',
#   '准备',
#   '回家',
#   '好好',
#   '玩玩'],
#  ['本书',
#   'OOV',
#   '总体',
#   '感觉',
#   '老外',
#   '带',
#   '孩子',
#   '中国',
#   '人要',
#   '粗些',
#   'OOV',
#   '其实',
#   'OOV',
#   '本来',
#   '不用',
#   '太过',
#   '细致',
#   'OOV',
#   '照样',
#   '孩子',
#   '带',
#   'OOV',
#   '不能',
#   '孩子',
#   '放在',
#   '保险箱',
#   '里养',
#   'OOV',
#   '这书',
#   '挺',
#   'OOV',
#   '看看'],
#  ['游戏',
#   '质量',
#   '非常',
#   '高',
#   '真实度',
#   'OOV',
#   '画质',
#   'OOV',
#   '可玩性',
#   'OOV',
#   '想',
#   '体验',
#   '拉力赛',
#   '车手',
#   '朋友',
#   '绝对',
#   '错过',
#   '!',
#   '新手',
#   '不用',
#   '担心',
#   '难度',
#   '太高',
#   'OOV',
#   '游戏',
#   '难度',
#   '划分',
#   '非常',
#   'OOV',
#   '缺点',
#   '网友',
#   '都',
#   'OOV',
#   '配置',
#   '要求',
#   'OOV',
#   '汉化',
#   '质量',
#   'OOV',
#   '觉得',
#   '价格',
#   '高',
#   '朋友',
#   'OOV',
#   '稍微',
#   '几个',
#   '月',
#   '下来',
#   'OOV'],
#  ['喜欢',
#   '现实',
#   'OOV',
#   '矫',
#   '揉',
#   '诗',
#   'OOV',
#   '诗',
#   '时间',
#   '顺序排列',
#   'OOV',
#   '很',
#   '喜欢',
#   '封面',
#   'OOV'],
#  ['日系',
#   '不同',
#   'OOV',
#   '本书',
#   '风格',
#   '很大',
#   '气',
#   'OOV',
#   '很多',
#   '东西',
#   '很',
#   '实用',
#   'OOV',
#   '最后',
#   '图纸',
#   '非常',
#   '详细',
#   'OOV',
#   '简单',
#   '步骤',
#   '都',
#   '略过',
#   'OOV',
#   '最',
#   '紧要',
#   '关键点',
#   '都',
#   '写',
#   '清楚',
#   'OOV',
#   '印刷',
#   '精美',
#   'OOV',
#   '内容',
#   '详实',
#   'OOV',
#   '推荐',
#   '大家',
#   '购买',
#   'OOV'],
#  ['喜欢',
#   'OOV',
#   '质量',
#   '出',
#   '问题',
#   'OOV',
#   '夏新',
#   '机子',
#   '性价比',
#   '最好',
#   'OOV',
#   '质量',
#   '大',
#   '放心',
#   'OOV',
#   '机子',
#   'OOV',
#   '烦说',
#   'OOV',
#   '想',
#   '买',
#   'OOV',
#   '真的',
#   'OOV'],
#  ['没', '仔细', '感觉', '大辞典'],
#  ['本书',
#   '已经',
#   '完结',
#   'OOV',
#   '封面',
#   'OOV',
#   '壹',
#   'OOV',
#   '字',
#   'OOV',
#   '代表',
#   'OOV',
#   '三生',
#   '三世',
#   'OOV',
#   '彩虹',
#   '堂',
#   'OOV',
#   '推出',
#   'OOV',
#   '前世',
#   '今生',
#   '系列',
#   'OOV',
#   '第一本',
#   'OOV',
#   'OOV',
#   '三生',
#   '三世',
#   'OOV',
#   '第二本',
#   '大家',
#   '放心'],
#  ['建议',
#   '此书',
#   'OOV',
#   '客观',
#   '记录',
#   'OOV',
#   '不要',
#   '去',
#   '个人',
#   '议论',
#   'OOV',
#   '误导',
#   'OOV',
#   '值得一看',
#   '好书'],
#  ['步骤', '很', '详细', 'OOV', '很', '实在'],
#  ['剧集',
#   '太多',
#   '没',
#   '看全',
#   'OOV',
#   '电视',
#   '老放',
#   'OOV',
#   '看不全',
#   'OOV',
#   '干脆',
#   '买全',
#   '放',
#   '家里',
#   '慢慢',
#   'OOV'],
#  ['很', '喜欢', '小老头', 'OOV', '!'],
#  ['小孩',
#   '一年一度',
#   '生日',
#   '音乐会',
#   '当时',
#   '没能',
#   '去',
#   '现场',
#   'OOV',
#   '真遗憾',
#   '还好',
#   '这张',
#   'OOV',
#   '这唱',
#   '演唱会',
#   '小孩',
#   '真素',
#   '帅',
#   'OOV',
#   '米',
#   'OOV',
#   '关键',
#   '素',
#   '声音',
#   '好好',
#   '听',
#   'OOV',
#   '好好',
#   '听',
#   '顺便',
#   '吼',
#   '一声',
#   'OOV',
#   '成都',
#   'OOV',
#   '成都',
#   'OOV',
#   '成都'],
#  ['刚刚', '收到', '书', 'OOV', '很', '不错', 'OOV'],
#  ['不错', '!'],
#  ['快点',
#   '进货',
#   'OOV',
#   '已经',
#   '缺货',
#   '一点',
#   '日子',
#   'OOV',
#   '想',
#   '买',
#   '都',
#   '买',
#   '不了',
#   'OOV'],
#  ['孩子',
#   '很',
#   '帮助',
#   'OOV',
#   '印刷',
#   '质量',
#   '很',
#   'OOV',
#   'OOV',
#   '文字',
#   '错误',
#   '地方',
#   '很多',
#   'OOV',
#   '制作',
#   '很',
#   '粗糙',
#   'OOV'],
#  ['上部', 'OOV', '集', 'OOV', '这下', '半部', 'OOV', '集', '全部', '结束'],
#  ['OOV', '其实', '支持'],
#  ['都',
#   '最',
#   '喜欢',
#   '经典',
#   '国产',
#   '动画片',
#   'OOV',
#   '两岁半',
#   '儿子',
#   '好像',
#   '看不懂',
#   'OOV',
#   '更',
#   '喜欢',
#   '动画',
#   '书',
#   'OOV'],
#  ['卓越',
#   '网是',
#   'OOV',
#   '苹果',
#   '官方',
#   '唯一',
#   '网络',
#   '授权',
#   'OOV',
#   '确凿',
#   '证据',
#   '质量',
#   '到底',
#   'OOV',
#   '卓越',
#   '保证'],
#  ['宝宝', '做', '保健操', 'OOV', '讲解', '很', '详细', 'OOV', '真人', '示范', 'OOV'],
#  ['货'],
#  ['卓越',
#   '运费',
#   '上面',
#   '功夫',
#   'OOV',
#   '太',
#   '霸王',
#   '明骗',
#   '!',
#   '转帖',
#   '网站',
#   '收费',
#   '标准',
#   '!',
#   'OOV',
#   '普通',
#   '快递',
#   '送货上门',
#   '平邮',
#   '订单',
#   '配送费',
#   'OOV',
#   'OOV',
#   'OOV',
#   '配送',
#   '优惠',
#   'OOV',
#   '每张',
#   '订单',
#   '商品',
#   '金额满',
#   'OOV',
#   'OOV',
#   '以上',
#   'OOV',
#   '优惠',
#   'OOV',
#   '配送费',
#   'OOV',
#   'OOV',
#   '加急',
#   '送货上门',
#   '配送费',
#   'OOV',
#   '北京',
#   'OOV',
#   '上海',
#   'OOV',
#   '广州地区',
#   'OOV',
#   'OOV',
#   'OOV',
#   '地区',
#   'OOV',
#   'OOV',
#   'OOV',
#   '配送',
#   '优惠',
#   'OOV',
#   'OOV',
#   'OOV',
#   '每张',
#   '订单',
#   '享受',
#   '一次',
#   '配送',
#   '优惠',
#   'OOV',
#   'OOV',
#   '邮政',
#   '特快专递',
#   'OOV',
#   '配送费',
#   '收取',
#   '标准',
#   'OOV',
#   '配送费',
#   'OOV',
#   '基价',
#   'OOV',
#   'OOV',
#   '包裹',
#   'OOV',
#   'OOV',
#   '浮动价格',
#   '最后',
#   '一条',
#   'OOV',
#   '基本',
#   '费用',
#   'OOV',
#   '手机',
#   '一件',
#   'OOV',
#   'OOV',
#   '发',
#   '手机',
#   'OOV',
#   '运费',
#   'OOV',
#   'OOV',
#   '运费',
#   'OOV',
#   '以此',
#   '一件',
#   'OOV',
#   '递增',
#   'OOV',
#   '!',
#   '国内',
#   'OOV',
#   '标准',
#   '收费',
#   'OOV',
#   'OOV',
#   'OOV',
#   '邮局',
#   '砍价',
#   'OOV',
#   '一件',
#   '计算',
#   'OOV',
#   '卓越',
#   '收',
#   'OOV',
#   '每件',
#   'OOV',
#   '标准',
#   '收',
#   'OOV',
#   '!',
#   '国内',
#   '大城市',
#   '大城市',
#   '邮局',
#   '时限',
#   '到货',
#   'OOV',
#   '基本',
#   'OOV',
#   '天到',
#   'OOV',
#   'OOV',
#   '实际',
#   '收到',
#   '货是',
#   '!',
#   '大概',
#   'OOV',
#   '左右',
#   'OOV',
#   '这是',
#   'OOV',
#   '!',
#   '当天',
#   '订单',
#   '基本',
#   '当天',
#   '货',
#   '发出',
#   'OOV',
#   '邮局',
#   'OOV',
#   '时限',
#   '到货',
#   '应该',
#   'OOV',
#   '收到',
#   '货',
#   'OOV',
#   '邮局',
#   '卓越',
#   '跟踪',
#   '货',
#   '走向',
#   'OOV',
#   '发现',
#   '卓越',
#   '邮寄',
#   '方式',
#   '经济',
#   '快递',
#   'OOV',
#   'OOV',
#   '!',
#   '邮局',
#   '客服',
#   '电话',
#   '解释',
#   '!',
#   '欺骗',
#   '!',
#   '标准',
#   '邮寄',
#   '方式',
#   '收取',
#   '费用',
#   '却',
#   '没有',
#   '使用',
#   '!',
#   '没',
#   '得到',
#   '卓越',
#   '满意',
#   '答复',
#   'OOV',
#   '长',
#   '买',
#   '东西',
#   '兄弟',
#   '电话',
#   '咨询',
#   'OOV',
#   '卓越',
#   '邮局',
#   '综合',
#   '解释',
#   '如下',
#   'OOV',
#   '电子产品',
#   '电池',
#   '所有',
#   '产品',
#   '允许',
#   '走',
#   'OOV',
#   '特快专递',
#   'OOV',
#   '只能',
#   '走',
#   '经济',
#   '快递',
#   '铁路运输',
#   'OOV',
#   '收费',
#   '已经',
#   '属于',
#   '霸王',
#   '条款',
#   '!',
#   '卓越',
#   '明',
#   '知道',
#   '不能',
#   '发',
#   '特快专递',
#   '却',
#   '表明',
#   '发',
#   '经济',
#   '快递',
#   '!',
#   '太',
#   '差劲',
#   'OOV',
#   '大家',
#   '算算',
#   '经济',
#   '快递',
#   '走',
#   '铁路',
#   'OOV',
#   '费用',
#   'OOV',
#   '公斤',
#   '以内',
#   '收费',
#   'OOV',
#   '!',
#   '手机',
#   '运费',
#   '卓越',
#   '赚取',
#   'OOV',
#   '血汗钱',
#   'OOV',
#   '看似',
#   '收费',
#   '收',
#   'OOV',
#   '每件',
#   'OOV',
#   '实际',
#   '收',
#   'OOV',
#   'OOV',
#   '却',
#   '蒙在鼓里',
#   'OOV',
#   '欺诈',
#   'OOV',
#   '绝对',
#   '欺诈',
#   'OOV',
#   '文笔',
#   '朋友',
#   'OOV',
#   '希望',
#   '发现',
#   '写',
#   '更好',
#   '卓越',
#   '合理',
#   '运输',
#   '费用',
#   'OOV',
#   '觉得',
#   '有用',
#   '支持',
#   '一下',
#   'OOV',
#   '!'],
#  ['书中',
#   '阐述',
#   '道理',
#   '大家',
#   '都',
#   '明白',
#   'OOV',
#   '难',
#   '作者',
#   '能够',
#   '很',
#   '简单',
#   '小',
#   '故事',
#   '讲述',
#   '出来',
#   'OOV',
#   '很多',
#   '感同身受',
#   '地方',
#   'OOV',
#   '是否',
#   '改变',
#   '生活'],
#  ['版本',
#   '书',
#   '几乎',
#   '都',
#   '买',
#   '!',
#   '纸张',
#   '很',
#   'OOV',
#   '翻译',
#   '不错',
#   '对照',
#   '英文原版',
#   'OOV',
#   '中美',
#   '混血儿',
#   'OOV',
#   '中英文',
#   '都',
#   '还过得去',
#   'OOV',
#   '觉得',
#   '很',
#   '!',
#   '想',
#   '买',
#   '一定',
#   '不会',
#   '后悔',
#   '!',
#   '极力推荐',
#   '!',
#   'OOV',
#   'OOV',
#   '!'],
#  ['每一', '首都', '很', '经典', 'OOV', '值得', '收藏'],
#  ['不错', 'OOV', '老师', '推荐', 'OOV', '找', '学期', 'OOV', '终于', '找到'],
#  ['讲', '很', '简略', 'OOV', '大家', '风范', '非常', '值得', '感受', 'OOV'],
#  ['请问', '此款', '机器', '颜色', '普通', '版', 'OOV', '黑', '不同', '卓越', '客服', '帮', '一下'],
#  ['我刚',
#   '买好',
#   'OOV',
#   '看过',
#   'OOV',
#   '效果',
#   '不错',
#   '!',
#   '送',
#   '写真',
#   '图册',
#   'OOV',
#   '写',
#   '很',
#   '灵',
#   '!',
#   '喜欢',
#   'OOV',
#   '朋友',
#   '用作',
#   '收藏',
#   '!'],
#  ['买', '知道', '奇妙', '!', '哈哈哈哈', '!'],
#  ['听后', '感觉', '不错', 'OOV'],
#  ['很帅', 'OOV', '壳子', '压坏', 'OOV', '运', '肯定', '饱受', '摧残', 'OOV'],
#  ['张悦然', '书', '都', '收藏', 'OOV', '这本', '例外', '!'],
#  ['游侠',
#   '汉化',
#   '事件',
#   '造成',
#   '双星',
#   'OOV',
#   '延期',
#   'OOV',
#   '月底',
#   '才',
#   '发行',
#   '这么久',
#   '超爱',
#   'OOV',
#   '社的',
#   '游戏',
#   '强烈',
#   '支持',
#   '!'],
#  ['买',
#   '之前',
#   '是因为',
#   '排名',
#   '比较',
#   '靠前',
#   'OOV',
#   '买',
#   '去',
#   '以后',
#   '发现',
#   '确实',
#   '很',
#   '不错',
#   'OOV'],
#  ['无话可说', 'OOV', '不买', '绝对', '后悔', '!'],
#  ['个人', '觉得', '久', '石', '最近', '最好', '作品', 'OOV'],
#  ['排版',
#   '问题',
#   'OOV',
#   '页面',
#   '居中',
#   'OOV',
#   '可能',
#   '出版社',
#   '不能',
#   '正常',
#   '出版',
#   '次品',
#   '!'],
#  ['一本', '好书', 'OOV', '很', '完美'],
#  ['终于',
#   '认真',
#   '本书',
#   '完',
#   'OOV',
#   '很',
#   '不错',
#   'OOV',
#   '很',
#   '实用',
#   'OOV',
#   '经络',
#   '养生',
#   '方法',
#   '很',
#   '适合',
#   '这种',
#   '上班族',
#   '女性',
#   'OOV',
#   '感谢',
#   '萧',
#   '医生',
#   '!'],
#  ['OOV', '经典作品', 'OOV', '做', '此类', '游戏', '入门', '学习', 'OOV'],
#  ['我要', '找', 'OOV', '很少', '地方'],
#  ['思路', '很', '新颖', 'OOV', '值得', 'OOV'],
#  ['第一',
#   'OOV',
#   '信号',
#   '很',
#   '稳定',
#   'OOV',
#   '前面',
#   '网友',
#   '所说',
#   '信号',
#   '不好',
#   'OOV',
#   '就要',
#   '具体情况',
#   'OOV',
#   '很',
#   '多种',
#   '原因',
#   '都',
#   '造成',
#   '信号',
#   '不好',
#   'OOV',
#   'OOV',
#   '库存',
#   'OOV',
#   '收到',
#   '机子',
#   'OOV',
#   'OOV',
#   '月',
#   '下旬',
#   '出厂',
#   'OOV',
#   '第三',
#   'OOV',
#   '电池',
#   '很',
#   '耐用',
#   'OOV',
#   '一块',
#   '充满',
#   '电池',
#   '至少',
#   '待机',
#   'OOV',
#   'OOV',
#   '一点',
#   'OOV',
#   '制式',
#   'OOV',
#   '手机',
#   '强',
#   '很多',
#   '!',
#   'OOV',
#   '好评',
#   '!'],
#  ['之前',
#   '买',
#   '几个',
#   '游戏',
#   'OOV',
#   '都',
#   '玩',
#   '不了',
#   'OOV',
#   '没有',
#   '注意',
#   '后面',
#   '操作系统',
#   '里面',
#   '没有',
#   '写',
#   'OOV',
#   '麻烦',
#   '高人',
#   '指点',
#   'OOV'],
#  ['爱好',
#   '中华',
#   '传统',
#   '文化',
#   '一部',
#   '很',
#   '记录片',
#   'OOV',
#   '没有',
#   '教课',
#   '书',
#   '枯燥',
#   'OOV',
#   '不似',
#   '工具书',
#   '艰涩',
#   '难懂',
#   'OOV',
#   '马未',
#   '都',
#   '先生',
#   '渊博',
#   '学识',
#   '娓娓道来',
#   'OOV',
#   '中国',
#   '古典家具',
#   '收藏',
#   'OOV'],
#  ['OOV',
#   '一贯',
#   '高',
#   '水准',
#   '音乐',
#   '素质',
#   'OOV',
#   '录音',
#   '品质',
#   'OOV',
#   '价格',
#   '引进',
#   '版',
#   '包装',
#   '赠品',
#   'OOV',
#   '真是',
#   '很红',
#   'OOV',
#   '这次',
#   '质量',
#   'OOV',
#   '音质',
#   '其实',
#   '用不着',
#   '原版',
#   '去',
#   'OOV',
#   '相信',
#   '原版',
#   '引进',
#   '版',
#   '同一个',
#   '普通',
#   '播放',
#   '器材',
#   '播放',
#   'OOV',
#   '绝大多数',
#   '歌迷',
#   '听不出',
#   '差别',
#   'OOV',
#   '引进',
#   '版有',
#   '差',
#   '原版',
#   'OOV',
#   '左右',
#   '真能',
#   '听',
#   '出',
#   '高音质',
#   '当然',
#   '借助',
#   '专业',
#   '器材',
#   '测评',
#   '出来',
#   'OOV',
#   '一句',
#   'OOV',
#   '这次',
#   '引进',
#   '版',
#   '音质',
#   '很',
#   '不错',
#   'OOV',
#   '歌手',
#   'OOV',
#   '歌曲',
#   'OOV',
#   '绝对值',
#   '听',
#   '!'],
#  ['OOV',
#   '号订',
#   'OOV',
#   '号',
#   '送到',
#   'OOV',
#   '里面',
#   '内容',
#   '超酷',
#   '!',
#   '书',
#   '都',
#   '铜版纸',
#   '印刷',
#   'OOV',
#   '手里',
#   '厚重',
#   '感觉',
#   '绝对值',
#   '!',
#   '世纪',
#   '卓越',
#   '快递',
#   '公司',
#   '邮寄',
#   '包装',
#   '很',
#   'OOV',
#   '注意',
#   'OOV',
#   '快递',
#   '公司',
#   '世纪',
#   '卓越',
#   'OOV',
#   '可能',
#   '不同',
#   '商品',
#   '快递',
#   'OOV',
#   '仙剑',
#   'OOV',
#   '豪华版',
#   '合众',
#   '天成',
#   '货运',
#   'OOV',
#   '购买',
#   '三个',
#   '物品',
#   '放在',
#   '纸盒',
#   '箱里',
#   'OOV',
#   '都',
#   '垫',
#   '泡沫',
#   '防止',
#   '震动',
#   'OOV',
#   '贴心',
#   '!',
#   '空之',
#   '轨迹',
#   'OOV',
#   '出',
#   '这种',
#   'OOV',
#   '不用',
#   '倒霉',
#   '网络',
#   '激活',
#   '!'],
#  ['喜欢',
#   'OOV',
#   '编辑',
#   '不能',
#   'OOV',
#   '详细信息',
#   '写',
#   '清楚',
#   '配音',
#   '想',
#   '知道',
#   '配音',
#   'OOV'],
#  ['近',
#   '两岁',
#   '女儿',
#   '非常',
#   '喜欢',
#   'OOV',
#   '碟片',
#   '质量',
#   '不错',
#   'OOV',
#   'OOV',
#   '寸',
#   '宽',
#   '屏放',
#   '很',
#   '清晰',
#   'OOV'],
#  ['内容',
#   'OOV',
#   '值得',
#   '收藏',
#   'OOV',
#   '帮助',
#   '摆平',
#   '心态',
#   'OOV',
#   '年代',
#   '听',
#   '进去',
#   '教育',
#   'OOV',
#   '总算',
#   '例外',
#   'OOV'],
#  ['老板', 'OOV', '进货', '郁闷'],
#  ['很', '不错', '很', '喜欢', '值得', '购买'],
#  ['整体',
#   '不错',
#   'OOV',
#   '词汇量',
#   'OOV',
#   '好些',
#   '基础',
#   '词汇',
#   '都',
#   '省略',
#   'OOV',
#   '比较',
#   '适合',
#   '单词',
#   '量',
#   '大',
#   '同学',
#   'OOV',
#   '基础',
#   '不太好',
#   '同学',
#   '灰楼',
#   '很多',
#   '重要',
#   '单词',
#   'OOV'],
#  ['有点', '味道', 'OOV', '孩子', '很', '喜欢'],
#  ['买',
#   '父母',
#   '礼物',
#   'OOV',
#   '没用',
#   '多久',
#   'OOV',
#   '很',
#   '开心',
#   'OOV',
#   '应该',
#   '不错',
#   'OOV'],
#  ['送来', '觉得', '书', '有点', '蹭', '总体', '里面', '内容', '非常', '不错', '很'],
#  ['绝对', '好听', 'OOV', '歌坛', '需要', '声音'],
#  ['这部',
#   '戏',
#   '曾经',
#   '看过',
#   '很',
#   '多次',
#   'OOV',
#   '年代',
#   '久',
#   'OOV',
#   'OOV',
#   '剧情',
#   '丰富',
#   'OOV',
#   '演员',
#   '表演',
#   '很',
#   '到位',
#   'OOV',
#   '尤其',
#   '办公室',
#   '争斗',
#   'OOV',
#   '很',
#   '值得一看',
#   'OOV',
#   '颇',
#   '提醒',
#   'OOV',
#   '没',
#   'OOV',
#   '知道',
#   '质量',
#   'OOV',
#   'OOV',
#   '很',
#   '相信',
#   '卓越'],
#  ['南拳', '妈妈', '歌曲', '很', 'OOV', '可惜', '版本', '歌曲', '可惜', '不全', '!'],
#  ['很',
#   '久',
#   '终于',
#   '上市',
#   '!',
#   '开心',
#   '!',
#   '从中',
#   '学到',
#   '很多',
#   '职场',
#   '智慧',
#   'OOV',
#   '看到',
#   'OOV',
#   '极品',
#   '男人',
#   'OOV'],
#  ['OOV', '感觉', '重复', '样子'],
#  ['质量', '不错', '!'],
#  ['OOV',
#   'OOV',
#   '降到',
#   'OOV',
#   '肯定',
#   '买',
#   'OOV',
#   '毕竟',
#   'OOV',
#   '买',
#   '很多',
#   '东西',
#   'OOV',
#   '信得过'],
#  ['总体',
#   '这部',
#   '片子',
#   '很多',
#   '地方',
#   'OOV',
#   '一部',
#   'OOV',
#   '分钟',
#   '片子',
#   'OOV',
#   '内容',
#   '不够',
#   '详细',
#   'OOV',
#   '毕竟',
#   '紫禁城',
#   '几千年',
#   '悠久',
#   '历史',
#   '很',
#   '难',
#   '压缩',
#   '短',
#   '时间',
#   'OOV',
#   '价格',
#   '有点',
#   '贵',
#   'OOV',
#   '很全',
#   'OOV',
#   '估计',
#   '很少',
#   '人能',
#   '去',
#   '买',
#   'OOV'],
#  ['编辑', '很', 'OOV'],
#  ['痘',
#   '印',
#   '都',
#   '一涂',
#   '涂',
#   '没',
#   'OOV',
#   '有点像',
#   '光影',
#   '魔术',
#   '手',
#   '软件',
#   '去',
#   '斑',
#   '功能',
#   'OOV',
#   '痣',
#   '只能',
#   '变淡',
#   'OOV',
#   '不能',
#   '全弄',
#   '没',
#   'OOV',
#   '全弄',
#   '没',
#   'OOV',
#   '颜色',
#   '涂好',
#   '深才行',
#   'OOV',
#   '周围',
#   '肌肤',
#   '颜色',
#   '对比',
#   '自然',
#   'OOV',
#   '大点',
#   '斑',
#   'OOV',
#   '只能',
#   '变淡',
#   'OOV',
#   '出',
#   'OOV',
#   '涂完',
#   '痘',
#   '印',
#   '肌肤',
#   '看起来',
#   '好好',
#   'OOV',
#   '误以为',
#   '真的',
#   '皮肤',
#   '健康',
#   'OOV',
#   '自我',
#   '催眠',
#   'OOV',
#   '呵呵',
#   'OOV',
#   '太',
#   '少量',
#   'OOV',
#   '晓得',
#   '多久',
#   'OOV'],
#  ['我来', '顶上去', 'OOV', '看看', '问题所在'],
#  ['OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV'],
#  ['买',
#   '版本',
#   '里面',
#   'OOV',
#   '张',
#   '安装盘',
#   'OOV',
#   '安',
#   '却',
#   '提示',
#   '安装',
#   '第四张',
#   '盘',
#   'OOV',
#   '搞',
#   '现在',
#   '游戏',
#   '玩',
#   '不了'],
#  ['OOV', '年前', '奥运会', 'OOV', '很', '值得', '珍藏', 'OOV'],
#  ['非常', '喜欢', '此类', '书籍', '!'],
#  ['好书', '一本', 'OOV', '不必', 'OOV'],
#  ['这套',
#   '教学片',
#   'OOV',
#   '浅显易懂',
#   'OOV',
#   '很',
#   '幽默',
#   'OOV',
#   '女儿',
#   '喜欢',
#   'OOV',
#   '经常',
#   '一边',
#   '一边',
#   '笑',
#   'OOV',
#   '学到',
#   '很多',
#   '汉字',
#   '知识',
#   'OOV',
#   '一起',
#   '学到',
#   '很多',
#   '知道',
#   '知识',
#   'OOV',
#   '强力',
#   '推荐',
#   'OOV',
#   '学问',
#   '猫学',
#   '历史',
#   'OOV',
#   '通知',
#   '一声',
#   'OOV',
#   '教师',
#   '都',
#   '学问',
#   '猫',
#   '教',
#   '孩子',
#   'OOV',
#   '孩子',
#   '一写',
#   '学到',
#   '掌握',
#   '很多',
#   '知识',
#   'OOV',
#   '不会',
#   '厌学',
#   'OOV'],
#  ['真是',
#   '意外',
#   '价格',
#   'OOV',
#   '几本',
#   '一起',
#   '降一嘛',
#   'OOV',
#   '大家',
#   '买',
#   '起来',
#   '方便',
#   'OOV'],
#  ['感觉', '影片', '不错', 'OOV', 'OOV'],
#  ['外出', '朋友', '一定', '记得', '带', '这本', '最', '完善', 'OOV', '最', '真实', '自助游', '手册'],
#  ['卓越',
#   '买',
#   '十几年',
#   '碟',
#   'OOV',
#   '第一次',
#   '碰到',
#   '没法',
#   'OOV',
#   '都',
#   '知道',
#   '喜欢',
#   '老电影',
#   'OOV',
#   '买来',
#   '经常',
#   '看看',
#   '收藏',
#   'OOV'],
#  ['支持',
#   '抗议',
#   '!',
#   '支持',
#   'OOV',
#   '!',
#   '重申',
#   'OOV',
#   'OOV',
#   '!',
#   '希望',
#   '卓越',
#   '要犯',
#   '低级',
#   '错误',
#   '!'],
#  ['很', '不错', 'OOV', '喜欢'],
#  ['搞',
#   '好像',
#   '很',
#   '复杂',
#   'OOV',
#   '玩',
#   '一盘',
#   '明白',
#   'OOV',
#   '很',
#   '容易',
#   '上手',
#   '游戏',
#   'OOV',
#   '适合',
#   '多人',
#   'OOV'],
#  ['喜欢', 'OOV', '买来', '学', '英语', 'OOV'],
#  ['非常', '喜欢', '一部', '电视', 'OOV', '破案', '过程', '非常', '过瘾'],
#  ['学期',
#   '学校',
#   '辅修',
#   '一门',
#   '法语',
#   'OOV',
#   '本人',
#   '很',
#   '爱',
#   '听歌',
#   'OOV',
#   '买',
#   '东东',
#   '帮助',
#   '偶',
#   '学习',
#   '法语',
#   'OOV',
#   '里面',
#   '收录',
#   '歌',
#   '超多',
#   'OOV',
#   '大家',
#   '熟知',
#   'OOV',
#   '依莲',
#   'OOV',
#   'OOV',
#   '蝴蝶',
#   'OOV',
#   '都',
#   '里面',
#   'OOV',
#   '两首歌',
#   'OOV',
#   '很多',
#   '很',
#   '听的歌',
#   '绝对',
#   '以前',
#   '听',
#   '没听说过',
#   'OOV',
#   '嘿嘿',
#   'OOV',
#   '真是',
#   '过瘾',
#   'OOV',
#   'OOV',
#   '附有',
#   '歌词',
#   'OOV',
#   '打算',
#   '两天',
#   '学唱',
#   '法语歌',
#   'OOV',
#   '绝对',
#   '推荐',
#   '购买',
#   'OOV'],
#  ['书',
#   '真的',
#   '写',
#   '很',
#   '不错',
#   'OOV',
#   '作者',
#   'OOV',
#   '度',
#   '全景',
#   '描写',
#   '杜',
#   '拉拉',
#   '职场',
#   '生活',
#   'OOV',
#   '书中会',
#   '很',
#   '实际',
#   '讲',
#   '平级',
#   '处理',
#   '关系',
#   'OOV',
#   '书中',
#   '很少',
#   '笔墨',
#   '描写',
#   '主人公',
#   '爱情',
#   'OOV',
#   '却',
#   '很',
#   '深刻',
#   'OOV',
#   '完',
#   '本书',
#   'OOV',
#   '外企',
#   '职员',
#   'OOV',
#   '都',
#   '觉得',
#   '受益',
#   '颇'],
#  ['说实话',
#   '没',
#   '玩',
#   'OOV',
#   '最近',
#   '游戏',
#   '出',
#   '很多',
#   'OOV',
#   '一下子',
#   '都',
#   '买',
#   '玩不过来',
#   'OOV',
#   '今天',
#   '看见',
#   '卓越',
#   '邮件',
#   'OOV',
#   '售后',
#   '态度',
#   'OOV',
#   '几句',
#   'OOV',
#   '无论是',
#   '产品',
#   '质量',
#   '卓越',
#   '服务态度',
#   '配送',
#   '员',
#   '质量',
#   '都',
#   '没话说',
#   'OOV',
#   '非常',
#   'OOV',
#   '幻',
#   'OOV',
#   '本篇',
#   '一起',
#   '买',
#   'OOV',
#   '东西',
#   '每个',
#   '都',
#   '仔细',
#   '包',
#   '大大的',
#   '塑料',
#   '泡沫',
#   'OOV',
#   '放在',
#   '箱子',
#   'OOV',
#   '派送',
#   '员',
#   '拿出',
#   '刀',
#   '当场',
#   '划开',
#   '里面',
#   'OOV',
#   '确定',
#   '签字',
#   'OOV',
#   '拆',
#   '包装',
#   '都',
#   '不行',
#   'OOV',
#   '笑',
#   '哈尔滨',
#   'OOV',
#   '很',
#   '冷',
#   'OOV',
#   '派送',
#   '员来',
#   '打哆嗦',
#   'OOV',
#   '十分',
#   '感动',
#   'OOV',
#   'OOV',
#   '卓越',
#   '一系列',
#   '服务',
#   'OOV',
#   '质量',
#   '很',
#   '高',
#   'OOV'],
#  ['本书', '不错', '!', '出来', 'OOV', '六哥', '花', '很多', '心血', '上面', '!', '推荐', '一下'],
#  ['看过', 'OOV', '据说', '好多', '电影', '特效', '都', '做', '出来', 'OOV'],
#  ['超级', '喜欢', '这张', '专辑'],
#  ['东西', '质量', '不错', 'OOV', '值得', '一买', 'OOV', '价格', '公道'],
#  ['爸爸', 'OOV', '觉得', '不错', 'OOV', '跟着', '练练', '太极拳', '健身', '很', '合适'],
#  ['便宜', '很', '目前', '没', '出', '问题', '买', '好几个', '月'],
#  ['去',
#   '电影院',
#   '看过',
#   'OOV',
#   '很',
#   '感动',
#   'OOV',
#   '特地到',
#   '卓越',
#   '买',
#   '张',
#   '正版',
#   '支持',
#   '一下',
#   'OOV'],
#  ['一看',
#   '实修',
#   '才能',
#   '写',
#   '出',
#   '书',
#   'OOV',
#   '了不起',
#   'OOV',
#   '阿姜查',
#   '道',
#   '出',
#   '佛法',
#   '真谛',
#   'OOV',
#   '世间',
#   '真谛',
#   'OOV',
#   '一部',
#   '实修',
#   '宝典',
#   'OOV',
#   '神秀',
#   '大师',
#   'OOV',
#   '身是',
#   '菩提树',
#   'OOV',
#   '心若',
#   '明镜',
#   '台',
#   'OOV',
#   '时时',
#   '勤',
#   '拂拭',
#   'OOV',
#   '勿',
#   '惹',
#   '尘埃',
#   '入世',
#   '法修起',
#   'OOV',
#   '再到',
#   '慧能',
#   '大师',
#   'OOV',
#   '菩提',
#   '本无树',
#   'OOV',
#   '明镜',
#   '亦非台',
#   'OOV',
#   '本来',
#   '无一物',
#   'OOV',
#   '何以',
#   '惹',
#   '尘埃',
#   '出世',
#   '法来',
#   '面对',
#   '五浊',
#   '恶世',
#   'OOV',
#   '很',
#   '清净',
#   'OOV'],
#  ['第一次',
#   '卓越',
#   '买',
#   '东西',
#   'OOV',
#   '韩版',
#   '已经',
#   'OOV',
#   '期待',
#   '引进',
#   '版',
#   '入手',
#   'OOV'],
#  ['OOV',
#   '地球',
#   '样子',
#   '看过',
#   '电影',
#   '之后',
#   'OOV',
#   '请',
#   '相信',
#   'OOV',
#   '从此',
#   '改变',
#   '生活',
#   '环保',
#   '口号',
#   'OOV',
#   '恐吓',
#   '威胁',
#   'OOV',
#   '人类',
#   '求生',
#   '本能',
#   'OOV',
#   '仅此而已'],
#  ['一段时间',
#   '降到',
#   '一千',
#   '九百多',
#   'OOV',
#   '两千多',
#   'OOV',
#   '两种',
#   '颜色',
#   '缺货',
#   'OOV',
#   '没有',
#   '选择',
#   '余地',
#   'OOV',
#   '降到',
#   '两千',
#   '以下',
#   '买',
#   '!'],
#  ['本书',
#   '出色',
#   '地方',
#   '在于',
#   '展示',
#   'OOV',
#   'OOV',
#   '里面',
#   '容易',
#   '产生',
#   '错误',
#   '使用',
#   '方法',
#   '进行',
#   '讨论',
#   'OOV',
#   '结合',
#   'OOV',
#   'OOV',
#   '新',
#   '功能',
#   'OOV',
#   '原理',
#   '解析',
#   'OOV',
#   '此书',
#   '知识',
#   '量',
#   '大',
#   'OOV',
#   '一本',
#   '长期',
#   '受用',
#   '书籍',
#   'OOV',
#   '必须',
#   '详细',
#   '咀嚼',
#   'OOV',
#   '翻查',
#   'OOV',
#   '加以',
#   '实践',
#   '思考',
#   '才能',
#   '读通',
#   'OOV',
#   '适合',
#   'OOV',
#   '编程',
#   '真正',
#   '感兴趣',
#   '人来',
#   '读',
#   'OOV'],
#  ['买',
#   'OOV',
#   'OOV',
#   '真是',
#   '太好了',
#   'OOV',
#   'OOV',
#   '白事会',
#   'OOV',
#   '夸',
#   '住宅',
#   'OOV',
#   '尤其',
#   '经典',
#   'OOV',
#   '这才',
#   '真正',
#   '典型',
#   '中国式',
#   '传统',
#   '幽默',
#   'OOV',
#   '加上',
#   '马老',
#   '特有',
#   '不温不火',
#   '风格',
#   'OOV',
#   '百听不厌',
#   'OOV',
#   '开粥',
#   '厂',
#   'OOV',
#   '版本',
#   '不太好',
#   'OOV',
#   '没有',
#   'OOV',
#   '曾子',
#   '曰',
#   'OOV',
#   '内容',
#   'OOV',
#   '逊色',
#   '不少',
#   'OOV',
#   'OOV',
#   '卓越',
#   '商品',
#   '介绍',
#   '目录',
#   'OOV',
#   '王朝',
#   'OOV',
#   '应该',
#   'OOV',
#   '天王',
#   '庙',
#   'OOV',
#   '庙',
#   'OOV',
#   '繁体字',
#   'OOV',
#   '广',
#   'OOV',
#   '下面',
#   'OOV',
#   'OOV',
#   '字',
#   'OOV',
#   '批评',
#   '一下',
#   'OOV'],
#  ['想',
#   '都',
#   '不用',
#   '想',
#   '预订',
#   'OOV',
#   '高兴',
#   'OOV',
#   '张杰',
#   '拥有',
#   '一把',
#   '很',
#   '嗓音',
#   'OOV',
#   '天生',
#   '歌者',
#   'OOV',
#   '终于',
#   '等到',
#   '新专辑',
#   'OOV',
#   '明天',
#   '过后',
#   'OOV',
#   '很',
#   '好听',
#   '名字',
#   'OOV',
#   '觉得',
#   '一定',
#   '一张',
#   '感人',
#   '唱片',
#   'OOV',
#   '都',
#   'OOV',
#   '很',
#   '抒情',
#   'OOV',
#   '很',
#   '励志',
#   'OOV',
#   '听',
#   '莫名',
#   '感动',
#   'OOV',
#   '天下',
#   'OOV',
#   '一首',
#   '中国',
#   '风',
#   '歌曲',
#   'OOV',
#   '很',
#   '特别',
#   'OOV',
#   '很',
#   '柔情',
#   'OOV',
#   '很',
#   '期待',
#   '歌曲',
#   'OOV',
#   '相信',
#   '迥然不同',
#   '歌',
#   'OOV',
#   '一定',
#   '很',
#   '好听',
#   'OOV',
#   '很',
#   '期待',
#   '听到',
#   '歌声',
#   'OOV',
#   '会唱出',
#   '歌曲',
#   '张杰',
#   'OOV',
#   '明天',
#   '过后',
#   'OOV',
#   '依然',
#   '爱',
#   '!'],
#  ['小孩', '喜欢', '反复', '多次'],
#  ['本书',
#   '帮',
#   '同事',
#   '买',
#   'OOV',
#   '好不好',
#   '不大清楚',
#   'OOV',
#   '同事',
#   '指定',
#   '本书',
#   'OOV',
#   '想必',
#   '用处'],
#  ['来到',
#   '页面',
#   '打算',
#   '买',
#   '错失',
#   '一张',
#   '专辑',
#   '!',
#   '担心',
#   'OOV',
#   '质量',
#   '送货',
#   '问题',
#   '不愿',
#   '卓越',
#   '买',
#   'OOV',
#   '一般来说',
#   '卓越',
#   '服务',
#   'OOV',
#   '请',
#   '考虑',
#   '别处',
#   '购买',
#   '这张',
#   '专辑',
#   'OOV',
#   '实在',
#   '太',
#   '好听',
#   'OOV'],
#  ['都',
#   '小时候',
#   '看着',
#   '长大',
#   '动画片',
#   'OOV',
#   '看着',
#   '勾起',
#   '童年',
#   '回忆',
#   'OOV',
#   '年代',
#   '太',
#   '久远',
#   'OOV',
#   '画面质量',
#   '实在',
#   '粗糙',
#   'OOV',
#   '色彩',
#   '不够',
#   '鲜艳',
#   'OOV',
#   '加上',
#   '故事',
#   '内涵',
#   '有点',
#   '偏深',
#   'OOV',
#   '两岁半',
#   '女儿',
#   '很',
#   '喜欢',
#   'OOV',
#   '倒',
#   '津津有味',
#   'OOV'],
#  ['课程',
#   '编排',
#   '明显',
#   '当时',
#   '教学内容',
#   '重新',
#   '编辑',
#   'OOV',
#   '当中',
#   '不能',
#   '很',
#   '衔接',
#   '地方',
#   'OOV'],
#  ['日本',
#   'OOV',
#   '二战',
#   '战败国',
#   'OOV',
#   '却',
#   '能够',
#   '短短的',
#   '数十年',
#   '发展',
#   '世界',
#   '顶级',
#   '性',
#   '强国',
#   'OOV',
#   '这是',
#   '举世',
#   '震惊',
#   'OOV',
#   '能够',
#   '极短',
#   '时间',
#   '内',
#   '发挥',
#   '极大',
#   '功效',
#   '能够',
#   '危亡',
#   '变得',
#   '生命力',
#   '能够',
#   '创伤',
#   '容易',
#   '振作起来',
#   '一点',
#   'OOV',
#   '拥抱',
#   '战败',
#   'OOV',
#   '拥抱',
#   '战败',
#   '第二次世界大战',
#   '日本',
#   'OOV',
#   '民族',
#   '角度',
#   'OOV',
#   '执政',
#   '角度',
#   '剖析',
#   '!',
#   '语言',
#   'OOV',
#   '文化',
#   'OOV',
#   '宗教',
#   '思想',
#   'OOV',
#   '本书',
#   '涉及',
#   '史料',
#   '丰富',
#   'OOV',
#   '写',
#   '全',
#   'OOV',
#   '美国',
#   '学者',
#   '日本',
#   '研究',
#   '精深',
#   'OOV',
#   '复杂',
#   '具体表现',
#   'OOV',
#   '本书',
#   '特点',
#   '非常规',
#   '性',
#   'OOV',
#   '诸多',
#   '隐性',
#   '分析',
#   '发展',
#   '日本',
#   'OOV',
#   '这是',
#   '最大',
#   '两点',
#   'OOV',
#   '本书',
#   '获',
#   '诸多',
#   '荣誉',
#   '保障',
#   'OOV',
#   '相信',
#   '读',
#   '本书',
#   '能够',
#   '更加',
#   '全方位',
#   '认识',
#   '日本',
#   '发展',
#   '之因',
#   'OOV',
#   '更加',
#   '享受',
#   '日本',
#   '不容',
#   '小觑',
#   '国家',
#   '真正',
#   '民族',
#   '精神',
#   '!'],
#  ['老公',
#   '很',
#   '忙',
#   'OOV',
#   '没有',
#   '时间',
#   '陪',
#   '去',
#   '孕妇',
#   '班',
#   'OOV',
#   '买',
#   '本书',
#   'OOV',
#   '在家',
#   '学习',
#   '运动',
#   'OOV',
#   '这书',
#   '很',
#   '喜欢',
#   'OOV',
#   '看书',
#   '学到',
#   '很多',
#   '东西',
#   'OOV',
#   '时间',
#   '安排',
#   '自由',
#   'OOV',
#   '喜欢',
#   'OOV'],
#  ['包装',
#   '歌词',
#   '做',
#   '都',
#   '很',
#   '精致',
#   'OOV',
#   '呵呵',
#   '送',
#   '东西',
#   '绝对',
#   '物超所值',
#   'OOV',
#   '整张',
#   '专辑',
#   '很',
#   '舒服',
#   'OOV',
#   '比小',
#   '宇宙',
#   '样子',
#   '好看',
#   'OOV',
#   '歌',
#   '好听',
#   'OOV',
#   '青',
#   '峯',
#   '大爱',
#   'OOV',
#   '!'],
#  ['都',
#   '名家',
#   '之作',
#   'OOV',
#   '不会',
#   '失望',
#   'OOV',
#   '历史',
#   '录音',
#   'OOV',
#   '音质',
#   '稍微',
#   '糙',
#   'OOV',
#   '理解',
#   'OOV'],
#  ['专辑',
#   '质量',
#   '确实',
#   '非常',
#   'OOV',
#   '感觉',
#   '最近',
#   '新索',
#   '涨价',
#   '厉害',
#   'OOV',
#   '当时',
#   '抽奖',
#   'OOV',
#   '块',
#   'OOV',
#   '现在',
#   '越来越',
#   '高',
#   'OOV',
#   '强烈要求',
#   '降价',
#   'OOV'],
#  ['题', 'OOV', '降点', '买'],
#  ['现在',
#   '时孕',
#   '后期',
#   'OOV',
#   '每天晚上',
#   '提前',
#   '上床',
#   '宝宝',
#   '讲故事',
#   'OOV',
#   '感觉',
#   'OOV',
#   '宝宝',
#   '很',
#   '期待',
#   '故事书',
#   '感觉',
#   '儿童',
#   '时期',
#   '接触',
#   'OOV',
#   '图画',
#   '大大的',
#   'OOV',
#   '很',
#   '可爱',
#   'OOV',
#   '颜色',
#   '鲜艳',
#   'OOV',
#   '以后',
#   '宝宝',
#   '使用'],
#  ['佛', '故事', 'OOV', '一段', '皈依', '历程'],
#  ['现在', '引进', '版', '质量', '越来越'],
#  ['本书',
#   '不错',
#   'OOV',
#   '实例',
#   '很多',
#   'OOV',
#   '步骤',
#   '一步',
#   '一步',
#   '完成',
#   'OOV',
#   '感觉',
#   '提高',
#   '很快',
#   'OOV',
#   '操作',
#   '描述',
#   '实际',
#   '情况',
#   '不符',
#   'OOV',
#   '很',
#   '令人费解',
#   'OOV',
#   '反复',
#   '实践',
#   '才',
#   '搞懂',
#   'OOV',
#   '就算',
#   '提高',
#   'OOV',
#   '本书',
#   'OOV',
#   '入门',
#   '教材',
#   '不错',
#   'OOV'],
#  ['录像',
#   '年代',
#   '比较',
#   '近',
#   'OOV',
#   '图像',
#   '声音',
#   '都',
#   '比较',
#   'OOV',
#   '三个',
#   '折子戏',
#   'OOV',
#   '时间',
#   '约',
#   '一百二十',
#   '分钟',
#   'OOV'],
#  ['掌握', '不会', '知识', 'OOV', '受易', '非浅'],
#  ['好久',
#   'OOV',
#   '終於',
#   '等到',
#   '上市',
#   '裡面',
#   '方子',
#   '作法',
#   '很多',
#   '很',
#   '豐富',
#   'OOV',
#   '值得',
#   '擁有',
#   '!'],
#  ['其实',
#   '以前',
#   '看过',
#   '两遍',
#   'OOV',
#   '很',
#   '长时间',
#   'OOV',
#   '看到',
#   '电台',
#   '重播',
#   '不由自主',
#   '跟着',
#   '看上',
#   'OOV',
#   '考虑',
#   '买',
#   '一套'],
#  ['OOV',
#   '打分',
#   'OOV',
#   '分',
#   '是因为',
#   '很',
#   '喜欢',
#   '这部',
#   '电影',
#   'OOV',
#   '卓越',
#   '真的',
#   '很',
#   '耽误',
#   '事',
#   '!',
#   'OOV',
#   '月',
#   'OOV',
#   '号',
#   '订单',
#   'OOV',
#   '上面',
#   '写',
#   'OOV',
#   '月',
#   'OOV',
#   '号',
#   '才能',
#   '送到',
#   '到时候',
#   '托',
#   'OOV',
#   '卓越',
#   '作风',
#   'OOV',
#   'OOV',
#   '月',
#   'OOV',
#   '号',
#   '事情',
#   'OOV',
#   '我定',
#   'OOV',
#   '本书',
#   '都',
#   '老师',
#   '规定',
#   '暑假',
#   '阅读',
#   '书籍',
#   'OOV',
#   'OOV',
#   '月初',
#   '就要',
#   '交',
#   '作业',
#   'OOV',
#   '书',
#   'OOV',
#   '半个',
#   '假期',
#   '都',
#   '过去',
#   'OOV',
#   'OOV',
#   '卓越',
#   '真的',
#   '很',
#   '不周到',
#   'OOV',
#   'OOV',
#   '一次',
#   'OOV',
#   '一天',
#   '送到',
#   'OOV',
#   '最慢',
#   'OOV',
#   'OOV',
#   '想不出',
#   '早',
#   '一点',
#   '送到',
#   'OOV',
#   '卓越',
#   '损失',
#   'OOV',
#   '毕竟',
#   '派送',
#   '员',
#   '都',
#   'OOV',
#   '卓越',
#   '下货',
#   'OOV',
#   '这次',
#   'OOV',
#   '月',
#   'OOV',
#   '号',
#   '之前',
#   '送',
#   '不到',
#   'OOV',
#   '再也',
#   '卓越',
#   '!'],
#  ['新版', '以前', '版本', '版式', '不同', 'OOV', '很', '不错', 'OOV'],
#  ['很', '喜欢', '本书', 'OOV', '学习', '完对', 'OOV', '操作', '很大', '进步', '!', '谢谢', '!'],
#  ['OOV', '都', 'OOV', '究竟', '货', '没货'],
#  ['非常', '书', 'OOV', '适合', '反复研究'],
#  ['急', '!'],
#  ['喜欢', '喜欢', 'OOV', '快', '看吧', '!'],
#  ['很', '不错', '瑜伽', '课程'],
#  ['几天', '没', '邮件', 'OOV', '缺货', '呜呜', '呜呜', '呜呜', 'OOV'],
#  ['某网', '才', 'OOV', '!'],
#  ['学习', '日语', '经典', 'OOV', '必备', '学习材料', 'OOV', '当然', '买'],
#  ['买',
#   'OOV',
#   '昨天',
#   '送来',
#   'OOV',
#   '对比',
#   '一下',
#   'OOV',
#   '原装',
#   'OOV',
#   '包装',
#   '真的',
#   '简单',
#   'OOV',
#   '薄薄的',
#   '塑料',
#   '小袋',
#   'OOV',
#   '插口',
#   'OOV',
#   '都',
#   '没有',
#   '用过',
#   '新品',
#   'OOV'],
#  ['买',
#   '好几本',
#   '图说',
#   '天下',
#   '觉得',
#   '很',
#   '图文并茂',
#   '学习',
#   '地理',
#   '很大',
#   '帮助',
#   '我会',
#   '继续',
#   '支持',
#   'OOV'],
#  ['颜色',
#   '很',
#   '鲜艳',
#   'OOV',
#   '很',
#   '适合',
#   '孩子',
#   '阅读',
#   'OOV',
#   '买',
#   '一个四岁',
#   '小姑娘',
#   'OOV',
#   '很',
#   '喜欢'],
#  ['新蛋网', '报价', '低', 'OOV', '中关村', '价格比', '便宜', '不少', 'OOV'],
#  ['不出所料', 'OOV', '里面', '塑料', '破损', '!', 'OOV', '碟', '都', '带', 'OOV', '!'],
#  ['加油', 'OOV', '陈绮贞', '!'],
#  ['OOV',
#   '久',
#   'OOV',
#   '已经',
#   '台版',
#   'OOV',
#   '想',
#   '买',
#   '送给',
#   '朋友',
#   'OOV',
#   '快点',
#   '补足',
#   '资料',
#   'OOV',
#   '上货',
#   '!',
#   'OOV',
#   '月',
#   'OOV',
#   '补充',
#   'OOV',
#   'OOV',
#   '效率',
#   'OOV',
#   '现在',
#   '介绍',
#   '裸着',
#   'OOV',
#   '补充',
#   '一部分',
#   'OOV',
#   '一秒',
#   '生命',
#   '神秘',
#   '嘉宾',
#   'OOV',
#   '没',
#   '听',
#   '披头',
#   '四',
#   '嘴裡',
#   '不会',
#   '唱著',
#   '爱',
#   '和平',
#   '没',
#   '看过',
#   '村上春树',
#   '脑中',
#   '不会',
#   '写出',
#   '诗',
#   '梦境',
#   '没',
#   '遇见',
#   '心中',
#   '不会',
#   '出现',
#   '爱情',
#   '现在',
#   '等待',
#   '著',
#   '闯进',
#   '生命',
#   '◎',
#   '等待',
#   '一年',
#   'OOV',
#   '终',
#   '於',
#   '等到',
#   '真正',
#   '冠军',
#   '出辑',
#   '第一届',
#   '星光',
#   '大道',
#   '冠军',
#   '全',
#   '亚洲',
#   '万眾',
#   '期待',
#   '首张',
#   '个人专辑',
#   '迷幻',
#   '慵懒',
#   '诗意',
#   '摇滚',
#   '态度',
#   'OOV',
#   '终',
#   '於',
#   '等到',
#   '百变',
#   '林',
#   '宥',
#   '嘉',
#   '◎',
#   '华语',
#   '乐坛',
#   '王牌',
#   '新秀',
#   '音乐',
#   '精心',
#   '调',
#   '製',
#   '精品',
#   '专辑',
#   '华研',
#   '唱片',
#   '全力',
#   '打造',
#   '歌坛',
#   '新人王',
#   '陈小霞',
#   'OOV',
#   '林夕',
#   'OOV',
#   '李泉',
#   'OOV',
#   '施人诚',
#   'OOV',
#   '小宇',
#   'OOV',
#   '郑楠',
#   'OOV',
#   '陈信延',
#   '华语音乐',
#   '顶尖',
#   '创作',
#   '联手',
#   '造林',
#   '宥',
#   '嘉',
#   '首张',
#   '专辑',
#   'OOV',
#   '华研',
#   '唱片',
#   '大手笔',
#   '宣传',
#   'OOV',
#   '演唱会',
#   'OOV',
#   '签唱会',
#   '双管齐下',
#   '造势',
#   '人气',
#   '买气',
#   '一网打尽',
#   'OOV',
#   '目标',
#   'OOV',
#   '歌坛',
#   '新人王',
#   '◎',
#   '打破纪录',
#   'OOV',
#   '更要',
#   '创造',
#   '纪录',
#   '发片',
#   '前林',
#   '宥',
#   '嘉',
#   '创下',
#   '两项',
#   '纪录',
#   'OOV',
#   '未',
#   '发片',
#   '举办',
#   '北',
#   'OOV',
#   'OOV',
#   '南',
#   '三场',
#   '大型',
#   '售票',
#   '演唱会',
#   'OOV',
#   '乐坛',
#   '第一',
#   'OOV',
#   '个人',
#   '特质',
#   'OOV',
#   '良好形象',
#   '超高',
#   '人气',
#   '成為',
#   '厂商',
#   '最',
#   '爱',
#   'OOV',
#   '未',
#   '发片',
#   '广告',
#   '代言',
#   '活动',
#   '邀约',
#   '不断',
#   'OOV',
#   '到处',
#   '都',
#   '得到',
#   '优质',
#   '林宥',
#   '嘉'],
#  ['现在', '买', '这款', 'OOV', '贵', '没', '去', '卖场', '问过', '希望', '了解', '建议', '谢'],
#  ['今天下午',
#   '收到',
#   '货',
#   'OOV',
#   '包装',
#   '很',
#   '整洁',
#   'OOV',
#   '打开',
#   'OOV',
#   '很',
#   '舒服',
#   '手感',
#   'OOV',
#   '外观',
#   '很漂亮',
#   'OOV',
#   '很',
#   '喜欢',
#   'OOV',
#   '以前',
#   '定过',
#   'OOV',
#   '美好',
#   'OOV',
#   '质量',
#   '不好',
#   'OOV',
#   '这次',
#   '很',
#   '不错',
#   'OOV',
#   '索客',
#   'OOV',
#   '质量',
#   '很',
#   'OOV',
#   '现在',
#   '正在',
#   '床上',
#   '打字',
#   'OOV',
#   '很',
#   '舒服',
#   'OOV',
#   '呵呵',
#   'OOV'],
#  ['没', '买', '菜谱', 'OOV', '一定', '买', '一本', 'OOV', '强烈推荐', '作者', '博客'],
#  ['软件', '比较', '有用', 'OOV', '学习', '关键', '用功', 'OOV', '当然', '因人而异', '喽', '!'],
#  ['送给',
#   '侄子',
#   '儿童节',
#   '礼物',
#   'OOV',
#   '学校',
#   '里订',
#   'OOV',
#   '很',
#   '担心',
#   '赶不及',
#   '送到',
#   'OOV',
#   '客服',
#   '电话',
#   'OOV',
#   '客服',
#   '妹妹',
#   '说会',
#   '帮',
#   '尽快',
#   '发出',
#   'OOV',
#   '超级',
#   '神速',
#   'OOV',
#   '第二天',
#   '!',
#   '侄子',
#   '很',
#   '喜欢',
#   'OOV',
#   '现在',
#   '小孩',
#   '开心',
#   'OOV',
#   '这种',
#   '寓教于乐',
#   '东西'],
#  ['挺不错', 'OOV'],
#  ['看过',
#   '阿婆',
#   '几部',
#   '作品',
#   'OOV',
#   '这部',
#   '最',
#   '喜欢',
#   '!',
#   '故事情节',
#   '严密',
#   'OOV',
#   '推理',
#   '信服'],
#  ['买', '江民', '杀毒', 'OOV', '升级版', 'OOV', '好用', 'OOV', '五星'],
#  ['音效', '非常', '棒', 'OOV', '听', '起来', '很', '舒服', 'OOV', '赞', '!'],
#  ['标准', '教学片', 'OOV', '很', '!', '贵', 'OOV'],
#  ['这本',
#   'OOV',
#   '买',
#   '回家',
#   '以后',
#   'OOV',
#   '几乎',
#   '天天',
#   '都',
#   '听',
#   '一遍',
#   'OOV',
#   '喜欢',
#   '李健',
#   '声音',
#   'OOV',
#   '声音',
#   '安静',
#   'OOV',
#   '思考',
#   'OOV',
#   '迷茫',
#   'OOV',
#   'OOV',
#   '天狐',
#   'OOV',
#   '电吉他',
#   'OOV',
#   '间奏',
#   'OOV',
#   'OOV',
#   '异乡人',
#   'OOV',
#   '松花江',
#   'OOV',
#   '平实',
#   '木吉他',
#   '伴奏',
#   'OOV',
#   '吉他',
#   '爱好者',
#   '更是',
#   '喜爱',
#   '!',
#   '翻开',
#   '歌词',
#   'OOV',
#   '看着',
#   '鲁豫写',
#   '续',
#   'OOV',
#   '看着',
#   '几张',
#   '发黄',
#   '老照片',
#   'OOV',
#   '看着',
#   '李',
#   '健全',
#   '哈尔滨',
#   '老',
#   '动物',
#   '院',
#   '合影',
#   '!',
#   '听',
#   '这位',
#   '家乡',
#   '歌手',
#   '唱歌',
#   'OOV',
#   '有着',
#   '说不出来',
#   '感觉',
#   '!',
#   '都',
#   '喝',
#   '松花江',
#   '长大',
#   'OOV'],
#  ['确实', '好书'],
#  ['经典',
#   'OOV',
#   '值得',
#   '收藏',
#   'OOV',
#   '清晰度',
#   '差',
#   'OOV',
#   '找到',
#   '最',
#   '清晰',
#   'OOV',
#   '系列',
#   '买'],
#  ['电脑包',
#   '不错',
#   'OOV',
#   '内部空间',
#   '不错',
#   'OOV',
#   '装蛮',
#   '东西',
#   'OOV',
#   '功能',
#   '分区',
#   '比较',
#   '合理',
#   'OOV',
#   'OOV',
#   '刚好',
#   '放进去',
#   'OOV'],
#  ['买',
#   '本书',
#   'OOV',
#   '一小半',
#   'OOV',
#   '觉得',
#   '写得',
#   '确实',
#   '不错',
#   'OOV',
#   '好多',
#   '以前',
#   '比较',
#   '模糊',
#   '概念',
#   '变得',
#   '清晰',
#   'OOV',
#   'OOV',
#   '书',
#   '送过来',
#   'OOV',
#   '里面',
#   '好多',
#   '页',
#   '都',
#   '皱',
#   'OOV',
#   '觉得',
#   '有点',
#   '不爽',
#   'OOV',
#   '呵呵',
#   'OOV',
#   '封面',
#   '正版',
#   'OOV',
#   'OOV',
#   '本书',
#   '不错',
#   'OOV'],
#  ['价钱', '不贵', '建议', '大家', '收藏'],
#  ['绝对',
#   '经典',
#   '经典',
#   'OOV',
#   '文笔流畅',
#   'OOV',
#   '引人入胜',
#   'OOV',
#   '连续',
#   '五个',
#   '晚上',
#   '熬夜',
#   '完',
#   'OOV'],
#  ['内容',
#   '挺',
#   '丰富',
#   'OOV',
#   '资料',
#   '设定',
#   '挺',
#   '精美',
#   'OOV',
#   '没',
#   '找到',
#   '礼品',
#   '卡',
#   'OOV',
#   '呵呵',
#   'OOV',
#   '可有可无',
#   '东东',
#   'OOV',
#   '希望',
#   '下次',
#   '买',
#   '东西',
#   '再少点',
#   '!'],
#  ['发短信',
#   '打电话',
#   '都',
#   '很',
#   '键盘',
#   '手感',
#   '很',
#   '打电话',
#   '发短信',
#   '用作',
#   '备用机',
#   '已经',
#   '很',
#   'OOV',
#   '个人',
#   '觉得',
#   '诺基亚',
#   '输入法',
#   '键盘',
#   '舒适度',
#   '就值',
#   '两百块',
#   'OOV',
#   '毕竟',
#   '厂家',
#   '几千块',
#   '手机',
#   '都',
#   '没',
#   '手感',
#   'OOV',
#   'OOV',
#   '人性化',
#   '烂',
#   'OOV',
#   '知道',
#   '想',
#   'OOV',
#   '两百多',
#   '买个',
#   '值得',
#   'OOV'],
#  ['买', '保修', '不会', '麻烦'],
#  ['畫質', '大部分', '還不錯', 'OOV', '值得', '珍藏', '!'],
#  ['起码', '现在', '为止', '出现', '问题', '一年'],
#  ['OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   '这书中',
#   '引用',
#   '很多',
#   '不同',
#   '观点',
#   'OOV',
#   '很多',
#   '阐述',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   '章节',
#   '末尾',
#   '总结',
#   'OOV',
#   '类似',
#   '小时候',
#   '抄',
#   '名人名言',
#   '!',
#   '书',
#   '最后',
#   '目录',
#   'OOV',
#   '分别',
#   '介绍',
#   '书',
#   '引用',
#   '对象',
#   '简介',
#   '!',
#   '作者',
#   '穿引',
#   '作用',
#   '!',
#   '书中',
#   '很多',
#   '地方',
#   '引用',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   '前一阵子',
#   '一类',
#   '书籍',
#   'OOV',
#   '了解',
#   '本书',
#   'OOV',
#   '后来',
#   '美国',
#   'OOV',
#   '查',
#   '一下',
#   'OOV',
#   '真的',
#   '很火',
#   '!',
#   '目前',
#   '国内',
#   '书',
#   '仿照',
#   '本书',
#   '写',
#   'OOV',
#   '作者',
#   '名',
#   '第一个',
#   '写',
#   'OOV',
#   '秘密',
#   'OOV',
#   'OOV',
#   '应该',
#   '不错',
#   '研究',
#   'OOV',
#   'OOV',
#   'OOV',
#   '文章内容',
#   '创意',
#   '很',
#   '新颖',
#   'OOV',
#   '独特',
#   'OOV',
#   '一系列',
#   '类似',
#   '名人名言',
#   '文章',
#   'OOV',
#   '从中',
#   '去',
#   '探索',
#   '需要',
#   'OOV',
#   '或者说',
#   '已经',
#   '遗失',
#   '东西',
#   'OOV',
#   '认识',
#   'OOV',
#   '改变',
#   '心态',
#   'OOV',
#   '快乐',
#   '生活',
#   '!',
#   '科学家',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   '很',
#   '唯心',
#   'OOV',
#   '思维',
#   '变得',
#   'OOV',
#   '觉得',
#   'OOV',
#   '很多',
#   '东西',
#   '相信',
#   'OOV',
#   '去',
#   '努力',
#   '!',
#   '最终',
#   '实现',
#   'OOV',
#   '梦想',
#   '加油',
#   '!',
#   '建议',
#   'OOV',
#   '英语水平',
#   'OOV',
#   'OOV',
#   '去',
#   '英文原版',
#   '!',
#   '问题',
#   '其实',
#   '犹豫',
#   '很',
#   '久',
#   'OOV',
#   '前一阵子',
#   '类似',
#   '书时',
#   'OOV',
#   '都',
#   '翻译',
#   '版',
#   'OOV',
#   '觉得',
#   '内容',
#   '容易',
#   '受',
#   '译者',
#   '影响',
#   'OOV',
#   '不能',
#   '更好',
#   '阅读',
#   '作者',
#   '本意',
#   'OOV',
#   '个人',
#   '学',
#   '翻译',
#   'OOV',
#   '觉得',
#   '无论是',
#   '直译',
#   '意译',
#   '都',
#   '存在',
#   '一定',
#   '问题',
#   '!',
#   '主张',
#   '原文',
#   'OOV',
#   '其实',
#   'OOV',
#   '之前',
#   '考虑',
#   '不要',
#   '买',
#   '原版',
#   'OOV',
#   '价格',
#   '蛮贵',
#   'OOV',
#   '书',
#   '将近',
#   'OOV',
#   '页',
#   'OOV',
#   '觉得',
#   '很',
#   '不划算',
#   'OOV',
#   '没有',
#   '买过',
#   '贵',
#   'OOV',
#   '后来',
#   '买',
#   'OOV',
#   '觉得',
#   '书',
#   '里面',
#   '学习',
#   'OOV',
#   '金钱',
#   '无法',
#   '衡量',
#   '!',
#   '英文版',
#   '才',
#   'OOV',
#   '真的',
#   '很',
#   '不错',
#   'OOV',
#   '全是',
#   '彩页',
#   'OOV',
#   '那种',
#   '超轻',
#   '纸',
#   'OOV',
#   '很',
#   '厚',
#   'OOV',
#   '光泽',
#   '那种',
#   '!',
#   'OOV',
#   '提个醒',
#   '那位',
#   '仁兄',
#   '建议',
#   '蛮',
#   '道理',
#   'OOV',
#   '编辑',
#   '考虑一下',
#   '!'],
#  ['OOV', '降价', 'OOV', '白色', '不来', '!', '准话', 'OOV', '花儿', '都', '谢', 'OOV'],
#  ['没有',
#   '全部',
#   '读完',
#   'OOV',
#   '才',
#   '看到',
#   '前面',
#   '几个',
#   '篇幅',
#   'OOV',
#   '英文',
#   '内容',
#   '很',
#   '简明',
#   '易懂',
#   'OOV',
#   '适合',
#   '学习',
#   '英文',
#   'OOV',
#   '中文翻译',
#   '不错',
#   'OOV',
#   '相当',
#   '精确',
#   'OOV',
#   '内容',
#   '不错',
#   '本书',
#   'OOV'],
#  ['上网',
#   '对战',
#   'OOV',
#   '歌曲',
#   '都',
#   '很多',
#   'OOV',
#   '毯子',
#   '踩',
#   '比较',
#   '舒服',
#   'OOV',
#   '很'],
#  ['相信',
#   '书',
#   '反映',
#   '出',
#   '品格',
#   'OOV',
#   '读完',
#   '此书',
#   'OOV',
#   '觉着',
#   '罗杰斯',
#   '挺',
#   '真诚',
#   '挺',
#   '亲切',
#   'OOV',
#   '女儿',
#   '爱',
#   '非常',
#   '感人',
#   'OOV',
#   '页数',
#   '价格',
#   'OOV',
#   '此书',
#   '太贵',
#   'OOV',
#   '品质',
#   'OOV',
#   '认为',
#   '物超所值',
#   'OOV',
#   '都',
#   '非常',
#   '宝贵',
#   '人生',
#   '经验',
#   'OOV'],
#  ['深入浅出', 'OOV', '实用性', '非常', '强', 'OOV', '生活', '很', '指导意义', 'OOV'],
#  ['OOV',
#   'OOV',
#   '演唱会',
#   '发行',
#   '唱片',
#   '带来',
#   '更',
#   '收入',
#   '流行',
#   '歌手',
#   'OOV',
#   '以来',
#   '发行',
#   '唱片',
#   '主要',
#   '收入',
#   '来源',
#   'OOV',
#   '演唱会',
#   '推销',
#   '唱片',
#   '手段',
#   'OOV',
#   '额外',
#   '收入',
#   'OOV',
#   '此一时',
#   'OOV',
#   '彼一时',
#   'OOV',
#   '时代',
#   '变化',
#   'OOV',
#   '唱片',
#   '演唱会',
#   '收入',
#   '比例',
#   '发生',
#   '变化',
#   'OOV',
#   '里程碑',
#   '英国',
#   '表演',
#   '专利',
#   '协会',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   '统计',
#   'OOV',
#   '英国',
#   '唱片业',
#   '收入',
#   'OOV',
#   '亿英镑',
#   'OOV',
#   '现场表演',
#   '收入',
#   '达到',
#   'OOV',
#   '亿英镑',
#   'OOV',
#   '演唱会',
#   '收入',
#   '第一次',
#   '超过',
#   '唱片',
#   '发行',
#   '收入',
#   'OOV',
#   '英国',
#   '表演',
#   '专利',
#   '协会',
#   '艺人',
#   '作者',
#   '收取',
#   '专利费',
#   'OOV',
#   'OOV',
#   '这是',
#   '划时代',
#   '变化',
#   'OOV',
#   '英国',
#   '表演',
#   '专利',
#   '协会',
#   '首席',
#   '经济师',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   '唱片',
#   '发行',
#   '演唱会',
#   '门票',
#   '收入',
#   'OOV',
#   '到达',
#   '里程碑',
#   'OOV',
#   '现场表演',
#   '收入',
#   '正式',
#   '超过',
#   '唱片',
#   '发行',
#   'OOV',
#   '其实',
#   'OOV',
#   '不少',
#   '艺人',
#   '早已',
#   '看到',
#   '唱片',
#   '市场萎缩',
#   'OOV',
#   '现场表演',
#   '畅通',
#   '潮流',
#   'OOV',
#   '近年来',
#   '越来越',
#   '艺人',
#   '歌手',
#   '巡演',
#   '增加收入',
#   'OOV',
#   '著名',
#   '歌星',
#   '麦当娜',
#   '最好',
#   '例子',
#   'OOV',
#   '有远见',
#   '精明',
#   '富有',
#   '创意',
#   '歌手',
#   '麦当娜',
#   'OOV',
#   '年同',
#   '演出',
#   '公司',
#   'OOV',
#   'OOV',
#   '签署',
#   '破纪录',
#   'OOV',
#   '亿美元',
#   '一揽子',
#   'OOV',
#   '合同',
#   'OOV',
#   '包括',
#   '所有',
#   '唱片',
#   '发行',
#   '演唱会',
#   '收入',
#   'OOV',
#   '近年来',
#   'OOV',
#   '麦当娜',
#   '几乎',
#   '连年',
#   '举行',
#   '大规模',
#   '巡演',
#   'OOV',
#   'OOV',
#   'OOV',
#   '世界',
#   '巡演',
#   '收入',
#   '高',
#   'OOV',
#   '亿美元',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   '巡演',
#   '收入',
#   '更',
#   '超过',
#   'OOV',
#   '亿美元',
#   'OOV',
#   '麦当娜',
#   '成为',
#   '过去',
#   '一年',
#   '世界',
#   '乐坛',
#   '收入',
#   '最高',
#   '流行',
#   '歌手',
#   'OOV',
#   '去年',
#   '收入',
#   '仅次于',
#   '麦当娜',
#   '一位',
#   '女歌手',
#   '–',
#   '加拿大',
#   '女歌手',
#   'OOV',
#   'OOV',
#   '世界',
#   '巡演',
#   '收入',
#   '达到',
#   'OOV',
#   '亿美元',
#   'OOV',
#   'OOV'],
#  ['三星',
#   '双卡',
#   '手机',
#   '性价比',
#   '一款',
#   '手机',
#   'OOV',
#   '购入',
#   '星期',
#   'OOV',
#   '使用',
#   '感觉',
#   '不错',
#   'OOV',
#   '手感',
#   '很',
#   'OOV',
#   '样子',
#   '喜欢',
#   '类型',
#   'OOV',
#   '呵呵',
#   'OOV'],
#  ['OOV',
#   '红标',
#   '碟版',
#   'OOV',
#   '世纪',
#   '五十年代',
#   '末期',
#   'OOV',
#   '经典',
#   '立体声',
#   '录音',
#   'OOV',
#   '日本',
#   '后期',
#   '重',
#   '制',
#   'OOV',
#   '星外星',
#   '引进',
#   '发行',
#   'OOV',
#   '菲德勒',
#   '波土顿',
#   '通俗',
#   '管弦乐团',
#   '获',
#   '不少',
#   '听众',
#   '喜爱',
#   'OOV',
#   '星外星',
#   '唱片',
#   '近年',
#   '赢得',
#   '一定',
#   '爱好者',
#   '拥',
#   '趸',
#   'OOV',
#   '波斯',
#   '市场',
#   'OOV',
#   '马刀',
#   '舞曲',
#   'OOV',
#   '经典名曲',
#   'OOV',
#   '多瑙河',
#   '之波',
#   'OOV',
#   '溜冰',
#   '圆舞曲',
#   'OOV',
#   '风流',
#   '寡妇',
#   'OOV',
#   '绿',
#   '袖子',
#   'OOV',
#   '听众',
#   '喜爱',
#   '曲目',
#   'OOV',
#   '精彩',
#   '集萃',
#   'OOV',
#   '播放',
#   '唱片',
#   '播放',
#   '设备',
#   '动态',
#   'OOV',
#   '音场',
#   '定位',
#   '一定',
#   '考验',
#   'OOV',
#   '适合',
#   '夜深人静',
#   '时小',
#   '音量',
#   '播放',
#   'OOV',
#   '星外星',
#   '宣传语',
#   'OOV',
#   '汽车音响',
#   '测试',
#   '必选',
#   'OOV',
#   '可能',
#   '不当',
#   'OOV',
#   '降低',
#   '室内',
#   'OOV',
#   '烧友',
#   '收藏',
#   '欲望',
#   'OOV'],
#  ['不愧为',
#   '大师',
#   'OOV',
#   '的确',
#   '经典之作',
#   '!',
#   '了解',
#   '中国',
#   '文化',
#   'OOV',
#   '想',
#   '了解',
#   '中国',
#   '文化',
#   'OOV',
#   '以为',
#   '了解',
#   '中国',
#   '文化',
#   '都',
#   '应该',
#   '看看',
#   '!'],
#  ['OOV',
#   '自然',
#   '所有',
#   'OOV',
#   '都',
#   '很',
#   '喜欢',
#   '喜欢',
#   '大自然',
#   '很多',
#   '事情',
#   '经历',
#   '不了',
#   '透过',
#   'OOV',
#   '片子',
#   '做到',
#   '愿望',
#   '收集',
#   '所有',
#   '自然',
#   'OOV',
#   '动物',
#   'OOV',
#   '碟片'],
#  ['我要', '一本', 'OOV'],
#  ['很', '学习', '资料', '!'],
#  ['不怎么', '搞', 'OOV', '一带', '上去', '皮肤', '过敏'],
#  ['这书',
#   '看起来',
#   '很',
#   '豪华',
#   'OOV',
#   '里面',
#   '讲',
#   '运用',
#   '幽默',
#   '方法',
#   '休闲',
#   '读一读',
#   'OOV',
#   '货到',
#   '通知',
#   '一下',
#   'OOV'],
#  ['今天',
#   '收到',
#   '货',
#   'OOV',
#   '正品',
#   'OOV',
#   '很',
#   '不错',
#   'OOV',
#   '再配',
#   'OOV',
#   '卡',
#   'OOV',
#   '很',
#   '!'],
#  ['经典作品', 'OOV', '值得', '拥有', 'OOV', '作品'],
#  ['电视',
#   '银杉',
#   '红树',
#   '两套',
#   'OOV',
#   '比较',
#   '赞同',
#   '评论者',
#   '丁丁',
#   '说法',
#   'OOV',
#   '个人',
#   '觉得',
#   '整篇',
#   '内容',
#   '衔接',
#   '挺',
#   'OOV',
#   '植物',
#   'OOV',
#   '动物',
#   'OOV',
#   '人文',
#   '之间',
#   '衔接',
#   '很',
#   '流畅',
#   'OOV',
#   '文字',
#   '很',
#   '优美',
#   'OOV',
#   '画面',
#   '取得',
#   '很',
#   '好看',
#   'OOV',
#   '很多',
#   '效果',
#   'OOV',
#   '譬如',
#   '鸟',
#   '捕食',
#   '虫子',
#   '瞬间',
#   'OOV',
#   '地方',
#   'OOV',
#   '清晰',
#   '到位',
#   'OOV',
#   '呵呵',
#   'OOV',
#   '这方面',
#   '外行',
#   'OOV',
#   '植物学',
#   '工作者',
#   'OOV',
#   '觉得',
#   '两集',
#   '内容',
#   '写',
#   '很',
#   'OOV'],
#  ['意思', '前两天', '刚下订', '降价', 'OOV', '有没有', '搞错'],
#  ['内容', '个人', '喜欢', '书', '质量', '不错'],
#  ['不错', 'OOV', '有点', '简单', 'OOV', '入门', '书'],
#  ['看林达',
#   '书',
#   '一种',
#   '享受',
#   'OOV',
#   '不断',
#   '反思',
#   'OOV',
#   '作者',
#   '美国',
#   '宪政',
#   '体制',
#   '当代',
#   '社会',
#   '琳琳',
#   '种种',
#   '复杂',
#   '问题',
#   '一种',
#   '简单',
#   '饶有趣味',
#   '叙述',
#   '方式',
#   '呈现',
#   '读者',
#   'OOV',
#   '专业',
#   '研究',
#   '美国',
#   'OOV',
#   '很多',
#   '读者',
#   '足以',
#   'OOV',
#   '林达',
#   '旅美',
#   '作家',
#   'OOV',
#   '旅美',
#   '学者',
#   'OOV',
#   '不要',
#   '对书',
#   '学术性',
#   '史实',
#   '性作',
#   '太高',
#   '要求',
#   'OOV',
#   '想',
#   '深入',
#   '了解',
#   '美国',
#   'OOV',
#   '大家',
#   '看看',
#   '北大',
#   '出版',
#   'OOV',
#   '原则',
#   '妥协',
#   'OOV',
#   '作者',
#   '华裔',
#   '美国',
#   '学者',
#   '王希',
#   '教授',
#   'OOV',
#   '王',
#   '教授',
#   '专攻',
#   '美国',
#   '宪政',
#   '史',
#   'OOV',
#   '黑人',
#   '史',
#   'OOV',
#   '书',
#   '可读性',
#   '很强',
#   'OOV',
#   '学术',
#   '价值',
#   '史料',
#   '价值',
#   '都',
#   '很',
#   '高',
#   'OOV',
#   '国内',
#   '研究',
#   '美国',
#   '宪政',
#   '体制',
#   '权威',
#   '著作',
#   'OOV',
#   '很',
#   '值得一看',
#   'OOV',
#   '看看',
#   '南京大学',
#   '美',
#   '文化',
#   '交流中心',
#   '东来',
#   '教授',
#   '撰写',
#   'OOV',
#   '宪政',
#   '历程',
#   '影响',
#   '美国',
#   '历史进程',
#   'OOV',
#   '司法',
#   '大案',
#   'OOV',
#   '宪政',
#   '舞台',
#   '美国最高法院',
#   '历史',
#   '轨迹',
#   'OOV',
#   '商务印书馆',
#   '出版',
#   'OOV',
#   '联邦',
#   '党人',
#   '文集',
#   'OOV',
#   '更是',
#   '研究',
#   '美国',
#   '政治',
#   '制度',
#   '经典',
#   'OOV',
#   '希望',
#   '完',
#   '书',
#   'OOV',
#   '大家',
#   '带来',
#   '一次',
#   '轻松愉快',
#   '美国',
#   '之旅'],
#  ['已经', '升级', '最新版', 'OOV'],
#  ['OOV',
#   '准',
#   '美国',
#   '第一夫人',
#   '蜜雪儿',
#   '赞',
#   '老公',
#   '朴实无华',
#   '法新社',
#   '华盛顿',
#   'OOV',
#   '日电',
#   '本月',
#   'OOV',
#   '成为',
#   '美国',
#   '第一夫人',
#   '蜜雪儿',
#   '欧',
#   '巴马',
#   'OOV',
#   'OOV',
#   '今天',
#   '接受',
#   '电视',
#   '专访',
#   'OOV',
#   '访谈',
#   '畅谈',
#   '「',
#   '朴实无华',
#   '准',
#   '总统',
#   '老公',
#   '初次',
#   '邂逅',
#   '点点滴滴',
#   'OOV',
#   '蜜雪儿',
#   '接受',
#   '美国',
#   '「',
#   '有线电视',
#   '新闻网',
#   'OOV',
#   '访问',
#   '时说',
#   'OOV',
#   '「',
#   '乍',
#   '听到',
#   '巴拉克',
#   '欧',
#   '巴马',
#   'OOV',
#   'OOV',
#   '名字',
#   'OOV',
#   '反应',
#   '可能',
#   'OOV',
#   '想',
#   '名字',
#   '「',
#   '心想',
#   '家伙',
#   '八成',
#   '有点',
#   '怪',
#   'OOV',
#   '可能',
#   '有点像',
#   '宅',
#   '男',
#   '书呆子',
#   'OOV',
#   '宅',
#   '男',
#   '书呆子',
#   '知识',
#   '份子',
#   '形象',
#   '在我心中',
#   '形塑',
#   'OOV',
#   '欧',
#   '巴马',
#   '之后',
#   '进入',
#   '芝加哥',
#   '法律',
#   '事务所',
#   '成为',
#   '同事',
#   'OOV',
#   '情况',
#   '随之',
#   '改观',
#   'OOV',
#   '更加',
#   '了解',
#   '欧',
#   '巴马',
#   'OOV',
#   '蜜雪儿',
#   'OOV',
#   '「',
#   '一拍即合',
#   'OOV',
#   '「',
#   '风趣',
#   '十足',
#   'OOV',
#   '谦逊',
#   '自抑',
#   'OOV',
#   '不致于',
#   '过分',
#   '矜持',
#   'OOV',
#   '十分',
#   '脚踏实地',
#   'OOV',
#   '身世',
#   '背景',
#   '比起',
#   '我来',
#   '奇特',
#   'OOV',
#   '蜜雪儿',
#   'OOV',
#   '欧',
#   '巴马',
#   '坚持',
#   '悠闲',
#   '自若',
#   '生活',
#   '方式',
#   'OOV',
#   '「',
#   '社区',
#   '组织',
#   '背景',
#   'OOV',
#   '华尔街',
#   '西装革履',
#   '那一型',
#   'OOV',
#   '蜜雪儿',
#   'OOV',
#   '老公',
#   '「',
#   '多年',
#   '没',
#   '改变',
#   'OOV',
#   '如今',
#   '穿着',
#   '衣裤',
#   '当年',
#   '俩',
#   '结婚',
#   'OOV',
#   '几条',
#   '裤子',
#   '破',
#   '穿',
#   'OOV',
#   '「',
#   '太',
#   '在意',
#   '别人',
#   '时尚',
#   '眼光',
#   'OOV',
#   '在意',
#   '议题',
#   'OOV'],
#  ['希望', '尽快', '便宜', '!'],
#  ['OOV', '最棒', '!'],
#  ['东西', '不错', 'OOV', '价格', '划算', 'OOV', 'OOV'],
#  ['很', '书', 'OOV', '享受'],
#  ['收货',
#   '比较满意',
#   'OOV',
#   '质量',
#   '不错',
#   'OOV',
#   '缺点',
#   'OOV',
#   '铃声',
#   '太',
#   'OOV',
#   '单调',
#   'OOV',
#   '子机',
#   '待机时间',
#   '太短',
#   'OOV',
#   '母机',
#   '断开',
#   '接电源',
#   'OOV',
#   '子机',
#   '无法',
#   '使用',
#   'OOV'],
#  ['精选集',
#   '每集',
#   '都',
#   '讲述',
#   '三个',
#   '著名',
#   '艺术家',
#   'OOV',
#   'OOV',
#   'OOV',
#   '很',
#   '实用',
#   'OOV',
#   '完后',
#   '收藏',
#   'OOV',
#   '拿来',
#   'OOV'],
#  ['不同', '听', 'OOV', '不同', '感觉', '!'],
#  ['想',
#   '基金',
#   '系统',
#   '了解',
#   'OOV',
#   '选购',
#   'OOV',
#   '出发点',
#   '入门',
#   'OOV',
#   'OOV',
#   '起来',
#   '请',
#   '合理',
#   '定位'],
#  ['音质', '很', '动听', 'OOV', '选曲', '很', '优秀', 'OOV', '特别', '推荐', 'OOV'],
#  ['小', '真不大', 'OOV', '够', '放点', '剩菜', '大', '普通', '饭盒', '大'],
#  ['白色',
#   'OOV',
#   '不能',
#   '黑色',
#   '供应商',
#   '东方',
#   'OOV',
#   '都',
#   '便宜',
#   '看到',
#   '好多',
#   '评论',
#   '卖得',
#   '手机',
#   '不好',
#   '卖得',
#   '手机',
#   '配件',
#   '迪信通',
#   '好多'],
#  ['主题', '内容', '非常', '健康', 'OOV', '引导', '孩子', '正确', '行为', '导向', 'OOV'],
#  ['这才',
#   '真正',
#   '经典',
#   'OOV',
#   '早晨',
#   '起床',
#   'OOV',
#   '打开',
#   '听',
#   'OOV',
#   '简直',
#   '一种',
#   '享受'],
#  ['都',
#   '狮子座',
#   'OOV',
#   '音乐',
#   '超棒',
#   'OOV',
#   '这张',
#   '专辑',
#   '引进',
#   '没有',
#   '删歌',
#   '这是',
#   '最好',
#   '卖点',
#   'OOV'],
#  ['非常', '喜欢', '清新', '小', '乐队'],
#  ['买', 'OOV', '音质', '好像', 'OOV', '好点', 'OOV', '样子', '比较', '有意思', 'OOV'],
#  ['童年', '美好', '回忆', 'OOV'],
#  ['用来', '收藏', 'OOV', '很', '值得'],
#  ['礼物', '送人', 'OOV', '挺', '!'],
#  ['书',
#   '拿到',
#   '以后',
#   'OOV',
#   '宝宝',
#   '爸爸',
#   '先看',
#   '津津有味',
#   'OOV',
#   '非常',
#   '想象力',
#   'OOV',
#   '现在',
#   '小孩子',
#   '真幸福',
#   'OOV',
#   '书',
#   '可供',
#   '学习',
#   'OOV'],
#  ['挺', 'OOV', '在家', '跟着', '一快', '跳', 'OOV', '省钱', '方便'],
#  ['超', '好听', '!', '希望', '去', '现场', '演出', '!'],
#  ['佛教', '兴趣', 'OOV', '不甚了解', '本书'],
#  ['比较', '好看'],
#  ['包装',
#   '挺',
#   '精美',
#   'OOV',
#   '剧本',
#   '纸',
#   '有点',
#   '糙',
#   '很全',
#   'OOV',
#   '中英对照',
#   'OOV',
#   '音质',
#   '很',
#   '清晰',
#   'OOV',
#   'OOV',
#   '很值',
#   '!',
#   '推荐',
#   '大家',
#   '买'],
#  ['非常', '经典', 'OOV', '回忆', '童年', 'OOV', '孩子', '爱', '听', 'OOV'],
#  ['内容', '不错', 'OOV', '做', '起来', '不易', 'OOV'],
#  ['很', '针对性', 'OOV', '实用性', 'OOV'],
#  ['内容',
#   '相当',
#   '完善',
#   '细致',
#   'OOV',
#   '讲解',
#   '深入浅出',
#   'OOV',
#   '算法',
#   '学习',
#   '必读',
#   '教材',
#   '!'],
#  ['唯一',
#   '遗憾',
#   '整张',
#   '盘',
#   '演奏',
#   '时间',
#   '短',
#   'OOV',
#   '维瓦尔第',
#   '那首',
#   '时间',
#   '实在',
#   '太短',
#   '!',
#   '整张',
#   '盘',
#   '总共',
#   'OOV',
#   '分钟',
#   'OOV'],
#  ['觉得',
#   '音乐',
#   '很',
#   '后来',
#   '慢慢',
#   '仔细',
#   '去',
#   '听',
#   '声音',
#   '很',
#   '干净',
#   '清新',
#   '总给',
#   '带来',
#   '一种',
#   '不同',
#   '感觉',
#   '视觉效果',
#   '很',
#   '心情',
#   '失落',
#   '走',
#   '出来',
#   '继续',
#   '快乐',
#   '之旅',
#   '心灵',
#   '放松',
#   '歌曲',
#   '很',
#   '喜欢',
#   '纯净',
#   '声音'],
#  ['一個', '多月', '!', '終於到', '!'],
#  ['继续',
#   'OOV',
#   '可惜',
#   '只能',
#   '继承',
#   '级别',
#   'OOV',
#   '道具',
#   '魔法',
#   '不能',
#   '继承',
#   'OOV',
#   '豪华版',
#   '官方',
#   '攻略',
#   '手册',
#   '太小',
#   'OOV',
#   '象',
#   'OOV',
#   '大',
#   '开面',
#   'OOV',
#   '快点',
#   '出',
#   'OOV',
#   '!'],
#  ['内容',
#   '大家',
#   '都',
#   '知道',
#   'OOV',
#   '效果',
#   '不错',
#   'OOV',
#   '挺',
#   '清晰',
#   'OOV',
#   '一盘',
#   '太长',
#   'OOV',
#   '好像',
#   '一个半',
#   '小时',
# ...
#   '能够',
#   '解答',
#   '方便',
#   '购买',
#   'OOV'],
#  ['不错', '书'],
#  ['一种',
#   '糟糕',
#   '预感',
#   'OOV',
#   '使命',
#   '召唤',
#   'OOV',
#   '永远',
#   '不会',
#   '国内',
#   '发行',
#   '正版',
#   'OOV',
#   '现在',
#   '加上',
#   'OOV',
#   '更',
#   '可能',
#   '上市',
#   'OOV',
#   '就算',
#   '国内',
#   '上市',
#   '十有八九',
#   '删减',
#   '版',
#   'OOV'],
#  ['不错', 'OOV', '很', '经典', 'OOV', '爱', '听', '国乐', '推荐'],
#  ['买',
#   'OOV',
#   '很',
#   '好听',
#   'OOV',
#   '整张',
#   '专辑',
#   '很',
#   '整体',
#   '感觉',
#   'OOV',
#   '不错',
#   '选择',
#   'OOV',
#   '大部分',
#   '歌',
#   '都',
#   '很',
#   '经典',
#   'OOV'],
#  ['包装',
#   '精美',
#   'OOV',
#   '音效',
#   '极好',
#   'OOV',
#   '朗诵',
#   '故事',
#   '编写',
#   '都',
#   '很',
#   'OOV',
#   '音乐',
#   'OOV'],
#  ['影响', '最大', '本书', 'OOV', '教会', '女人', '很多', '东西', 'OOV', '值得', '品味', '!'],
#  ['没有', '心情', '完整', 'OOV', '评价', '不错'],
#  ['OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV'],
#  ['广大观众', '带来', '娱乐', '相声', '!'],
#  ['价格', '不错', 'OOV', '东西', '不错'],
#  ['宝宝',
#   '喜欢',
#   'OOV',
#   '小',
#   '动物',
#   '找',
#   '身上',
#   '东西',
#   'OOV',
#   '每次',
#   '找到',
#   '高兴',
#   '手舞足蹈',
#   'OOV',
#   '推荐',
#   'OOV'],
#  ['一本',
#   '很',
#   '有趣',
#   '书',
#   'OOV',
#   '注意',
#   '平时',
#   '生活',
#   'OOV',
#   '身边',
#   '很多',
#   '有趣',
#   '细节',
#   '问题',
#   'OOV'],
#  ['久等',
#   'OOV',
#   '新宇',
#   '内部',
#   '人士',
#   '获得',
#   '一条',
#   '重要',
#   '小道消息',
#   'OOV',
#   '寰宇',
#   '重新',
#   '推出',
#   '仙剑',
#   '奇侠传',
#   '四',
#   '超',
#   '豪华版',
#   'OOV',
#   '以下',
#   '新宇',
#   '得到',
#   '独家',
#   '内容',
#   'OOV',
#   '并非',
#   '官方',
#   '正式',
#   '新闻',
#   'OOV',
#   '仅供',
#   '仙迷',
#   '朋友',
#   '参考',
#   'OOV',
#   '了解',
#   'OOV',
#   '国产',
#   '单机游戏',
#   '发展',
#   '举步维艰',
#   'OOV',
#   '寰宇',
#   '硕果仅存',
#   '单机',
#   '代理',
#   '厂商',
#   '依然',
#   '做',
#   '不懈',
#   '努力',
#   'OOV',
#   '内部人员',
#   '透露',
#   'OOV',
#   '寰宇',
#   '综合',
#   '各大',
#   '仙剑',
#   '社区论坛',
#   '玩友',
#   '意见',
#   'OOV',
#   '最终',
#   '讨论',
#   '决定',
#   'OOV',
#   '辜负',
#   '广大',
#   '仙迷',
#   '长久',
#   '期待',
#   'OOV',
#   '卖',
#   '一套',
#   '亏',
#   '一套',
#   '风险',
#   'OOV',
#   '依然',
#   '推出',
#   '款',
#   '绝对',
#   '值得',
#   '收藏',
#   '仙四超',
#   '豪华版',
#   '!',
#   'OOV',
#   '超',
#   '豪华版',
#   '成本',
#   '超高',
#   'OOV',
#   '本次',
#   '仙',
#   '四',
#   '超豪',
#   '以下',
#   '大',
#   '特点',
#   'OOV',
#   'OOV',
#   '周边产品',
#   '十分',
#   '精致',
#   '超值',
#   'OOV',
#   '不会',
#   '版本',
#   '渠道',
#   '单独',
#   '销售',
#   '!',
#   'OOV',
#   '超豪版',
#   '产量',
#   '十分',
#   '之少',
#   'OOV',
#   '不会',
#   '追加',
#   '生产',
#   '!',
#   'OOV',
#   '超豪版',
#   '外盒',
#   '超大',
#   '超重',
#   'OOV',
#   '让玩家',
#   '极大',
#   '满足感',
#   '!',
#   '附上',
#   '超豪',
#   '基本',
#   '信息',
#   'OOV',
#   '名称',
#   'OOV',
#   '仙剑',
#   '奇侠传',
#   '四超',
#   '豪华版',
#   '售价',
#   'OOV',
#   'OOV',
#   '含',
#   '运费',
#   'OOV',
#   '内容',
#   '物',
#   'OOV',
#   'OOV',
#   '之前',
#   '没',
#   '公布',
#   '没',
#   '出售',
#   '物品',
#   'OOV',
#   '很',
#   '厚道',
#   'OOV',
#   '限定',
#   '数量',
#   'OOV',
#   '套',
#   'OOV',
#   '极少',
#   'OOV',
#   '预定',
#   '发售日',
#   'OOV',
#   '夏天',
#   'OOV',
#   '最新消息',
#   'OOV',
#   '已经',
#   '确认',
#   'OOV',
#   '仙四超',
#   '豪华版',
#   'OOV',
#   '肯定',
#   '出',
#   'OOV',
#   '数量',
#   'OOV',
#   '极少',
#   'OOV',
#   '想',
#   '买来',
#   '收藏',
#   '仙迷',
#   '努力',
#   '抢购',
#   '噢',
#   'OOV',
#   '已经',
#   '确认',
#   '预购',
#   '日期',
#   'OOV',
#   'OOV',
#   '暑假',
#   'OOV',
#   '价钱',
#   '肯定',
#   'OOV',
#   '之间',
#   'OOV',
#   '更新',
#   '时间',
#   'OOV',
#   'OOV',
#   '月',
#   'OOV',
#   'OOV'],
#  ['不愧', '奥斯卡奖'],
#  ['没',
#   '练',
#   'OOV',
#   '教练',
#   '指导',
#   '应该',
#   '不难',
#   'OOV',
#   '教练',
#   '身材',
#   '很',
#   'OOV',
#   '很',
#   '美丽',
#   'OOV'],
#  ['书',
#   '新',
#   'OOV',
#   '页面',
#   '都',
#   '没有',
#   '破损',
#   'OOV',
#   '书',
#   '内容',
#   '很棒',
#   '!',
#   '外国',
#   '作者',
#   '写',
#   '确实',
#   '条理清晰',
#   'OOV',
#   '浅',
#   '深',
#   'OOV',
#   '没',
#   '一点',
#   '基础',
#   'OOV',
#   '感兴趣',
#   '学会',
#   'OOV',
#   '现在',
#   '看着',
#   '当时',
#   '学',
#   'OOV'],
#  ['应该',
#   '放在',
#   '游戏',
#   'OOV',
#   '放在',
#   '这害',
#   '找',
#   '老半天',
#   'OOV',
#   '当然',
#   '游戏',
#   '大爱',
#   'OOV'],
#  ['学校',
#   '读',
#   '大学',
#   'OOV',
#   '很',
#   '热',
#   'OOV',
#   '街边',
#   '买',
#   '觉得',
#   '质量',
#   '烂',
#   '没',
#   '安全感',
#   'OOV',
#   '加个',
#   'OOV',
#   '快买个',
#   '安心',
#   'OOV',
#   '很',
#   '满意',
#   'OOV',
#   '长得',
#   '很漂亮',
#   'OOV',
#   '还要',
#   '再来',
#   '买个',
#   'OOV'],
#  ['话题',
#   '推荐',
#   '十张',
#   '品质',
#   '不错',
#   '内地',
#   '引进',
#   '版',
#   '外国',
#   '唱片',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   'OOV',
#   '歌手',
#   '所属',
#   '国',
#   '发行',
#   '中国',
#   '内地',
#   '发行',
#   '都',
#   '五年',
#   '才',
#   '符合',
#   '话题',
#   '选择',
#   '范围',
#   'OOV'],
#  ['收到', 'OOV', '比较', 'OOV', '小孩', '喜欢', 'OOV', '没有', '拼图', 'OOV'],
#  ['OOV', '入门', '经典', '推荐', '!'],
#  ['新索出',
#   'OOV',
#   '精选',
#   '最',
#   '令人满意',
#   '一张',
#   'OOV',
#   '无论是',
#   '选',
#   '曲目',
#   'OOV',
#   '歌曲',
#   '版本',
#   'OOV',
#   '都',
#   '可谓',
#   '经典',
#   '之中',
#   '经典',
#   'OOV',
#   '算是',
#   '正版',
#   '最',
#   '便宜',
#   'OOV',
#   '以前',
#   '没有',
#   '买过',
#   'OOV',
#   'OOV',
#   '建议',
#   '这张',
#   '入手',
#   'OOV',
#   '唯一',
#   '缺憾',
#   '没有',
#   '歌词',
#   '这是',
#   '新索',
#   '内地',
#   '班',
#   '一贯作风',
#   'OOV',
#   '已经',
#   '熟知',
#   'OOV',
#   '歌',
#   '老迈',
#   '迷们',
#   'OOV',
#   '这张',
#   'OOV',
#   '米',
#   '买',
#   'OOV',
#   '建议',
#   '买',
#   '一张',
#   '收藏',
#   'OOV',
#   'OOV',
#   '其实',
#   '迈迈',
#   '老',
#   'OOV',
#   '没',
#   '买',
#   '这张',
#   'OOV',
#   '应该',
#   '都',
#   '买',
#   '原版',
#   '专辑',
#   '那种',
#   'OOV',
#   '这张',
#   '收藏',
#   '价值',
#   '价钱',
#   'OOV',
#   '买',
#   '一张',
#   '应该',
#   '很',
#   '值得',
#   'OOV',
#   '很多',
#   '曲目',
#   '专辑',
#   '版本',
#   '不同',
#   'OOV',
#   '确实',
#   '很多',
#   '更',
#   '喜欢',
#   '张里',
#   '版本',
#   'OOV',
#   '版本',
#   '更',
#   '商业化',
#   '听',
#   '首都',
#   '单曲',
#   'OOV',
#   '确实',
#   '一半左右',
#   '认为',
#   '更好',
#   'OOV',
#   '再有',
#   'OOV',
#   '新索',
#   '音质',
#   '不用',
#   '担心',
#   'OOV'],
#  ['很', '不错', 'OOV', '人物', '很', '可爱', 'OOV', '故事', '小', '道理', '大', 'OOV'],
#  ['包装', '封面', '很', '典雅', '大气', 'OOV', '故宫', '紫禁城', '城墙', '奇妙', '色彩', 'OOV'],
#  ['很',
#   '喜欢',
#   '!',
#   '纸',
#   '尺寸',
#   '太小',
#   'OOV',
#   '方便',
#   'OOV',
#   '如是',
#   'OOV',
#   '更好',
#   'OOV'],
#  ['一首歌',
#   '都',
#   '很',
#   '喜欢',
#   'OOV',
#   '没有',
#   '英文歌词',
#   '害',
#   '网上',
#   '搜索',
#   'OOV',
#   'OOV',
#   '躲',
#   'OOV',
#   'OOV',
#   '后面',
#   '那首歌',
#   '名字'],
#  ['可惜', '没', '歌词', 'OOV'],
#  ['赠送', '版本', 'OOV', '音乐剧', '版', '电影版'],
#  ['作曲者', '音乐', '描绘出', '花瓣', '纷纷', '飘荡', '情景', '聪明', '!'],
#  ['磁碟',
#   'OOV',
#   '张',
#   'OOV',
#   '绝不',
#   'OOV',
#   '压缩',
#   '碟',
#   'OOV',
#   '真正',
#   'OOV',
#   '画质',
#   'OOV',
#   '画面',
#   '非常',
#   '清晰',
#   'OOV',
#   '超过',
#   '电视台',
#   '播放',
#   '画质',
#   '水平',
#   'OOV',
#   'OOV',
#   '大家',
#   '熟悉',
#   '中国',
#   '国际',
#   '电视',
#   '总公司',
#   '根本',
#   '出版',
#   '压缩',
#   '碟',
#   '!'],
#  ['游戏', '!'],
#  ['作者',
#   '知识',
#   '很',
#   '丰富',
#   'OOV',
#   '获得',
#   '不少',
#   'OOV',
#   '一张',
#   '图',
#   '没有',
#   'OOV',
#   '文字',
#   '很',
#   '耐看'],
#  ['本书',
#   '作者',
#   '很',
#   '仔细',
#   'OOV',
#   '关心',
#   '成长',
#   '问题',
#   '都',
#   '涉及',
#   'OOV',
#   '与时俱进',
#   '更好',
#   'OOV',
#   '呵呵'],
#  ['OOV',
#   '一点',
#   '都',
#   '市场',
#   '行情',
#   'OOV',
#   '鄙视',
#   'OOV',
#   '越干越',
#   '没',
#   '市场',
#   'OOV',
#   '干',
#   'OOV'],
#  ['的确',
#   '小学生',
#   '爱玩',
#   '游戏',
#   'OOV',
#   '儿子',
#   '书',
#   '带',
#   '去',
#   '学校',
#   'OOV',
#   '几天',
#   '班上',
#   '同学',
#   '一下',
#   '课',
#   '凑',
#   '一块儿',
#   '研究',
#   '上面',
#   '游戏'],
#  ['第三部', '货'],
#  ['OOV', '买', 'OOV', '想', '玩', 'OOV'],
#  ['我要', '买', '这张', '专辑', 'OOV', '到货'],
#  ['喜欢', '!', '出版', '太晚', 'OOV', '第四季', '出', '很', '迫不及待', 'OOV'],
#  ['请问', 'OOV', '碟装', '完结', 'OOV', '分', '上部', '下部'],
#  ['喜欢', 'OOV'],
#  ['现在',
#   'OOV',
#   '已经',
#   '一年',
#   '本来',
#   '想',
#   '买',
#   'OOV',
#   '小心',
#   '看到',
#   '款',
#   '小心',
#   '喜欢',
#   '很',
#   '喜欢',
#   '降下',
#   '一定'],
#  ['OOV', 'OOV', 'OOV'],
#  ['发票', '实在', '太慢'],
#  ['喜欢', '类型', '书'],
#  ['卓越',
#   '网',
#   '服务态度',
#   'OOV',
#   '待客之道',
#   '卓越',
#   '网',
#   '服务态度',
#   'OOV',
#   '待客之道',
#   '卓越',
#   '网',
#   '买',
#   '东西',
#   'OOV',
#   '看看',
#   '运气',
#   'OOV',
#   '收到',
#   '好货',
#   '行',
#   '好运',
#   'OOV',
#   '收到',
#   '货品',
#   '問题',
#   'OOV',
#   '卓越',
#   '网就会',
#   '死',
#   '不认帐',
#   'OOV',
#   '就算',
#   '通過',
#   '网页',
#   '得到',
#   '確认',
#   'OOV',
#   '如有',
#   '問題',
#   '卓越',
#   '网',
#   '死',
#   '不认帐',
#   'OOV',
#   '如是',
#   '网页',
#   '提出',
#   'OOV',
#   '卓越',
#   '网',
#   '编辑',
#   '內容',
#   '网页',
#   '除掉',
#   '改正',
#   'OOV',
#   '並死',
#   '都',
#   '不会',
#   '认',
#   '回复',
#   '相关',
#   '问题',
#   '內容',
#   'OOV',
#   '反而',
#   '冇',
#   '看清',
#   '內容',
#   'OOV',
#   '就算',
#   '答应',
#   '处理',
#   '拖',
#   '字',
#   '政策',
#   'OOV',
#   '不了了之',
#   'OOV',
#   '大家',
#   '小心',
#   '!',
#   '卓越',
#   '网页',
#   '面向',
#   '編辑',
#   '提问',
#   '確',
#   '认得',
#   '非常',
#   '明確',
#   '回复',
#   '收到',
#   '货后',
#   '却',
#   '卓越',
#   '网',
#   '回复',
#   '三分之一',
#   'OOV',
#   '骗',
#   '三分之二',
#   'OOV',
#   '卓越',
#   '网',
#   '投诉',
#   '无数次',
#   'OOV',
#   '都',
#   '逃开',
#   '主题',
#   '隨便',
#   '回复',
#   'OOV',
#   '人员',
#   '回复',
#   '冇',
#   '看清',
#   '條款',
#   'OOV',
#   '已明確',
#   '提醒',
#   'OOV',
#   '卓越',
#   '网',
#   '提出',
#   '申诉',
#   '卓越',
#   '网才',
#   '改正',
#   'OOV',
#   '无法',
#   '改的己',
#   '卓越',
#   '网',
#   '全部',
#   '清除',
#   '掉',
#   '來',
#   '死',
#   '对政',
#   'OOV',
#   '接近',
#   '二十天',
#   '连续',
#   '投訴',
#   'OOV',
#   'OOV',
#   '月',
#   'OOV',
#   '下午',
#   '才',
#   '卓越',
#   '网',
#   '北京',
#   '中心',
#   '人员',
#   '來',
#   '电说',
#   '处理',
#   '问题',
#   'OOV',
#   '都',
#   '拿出',
#   '诚意',
#   '要求',
#   '卓越',
#   '赔',
#   '一半',
#   '三分之一',
#   'OOV',
#   '人员',
#   '答应',
#   '事情',
#   '反应',
#   '給上級並',
#   '回复',
#   'OOV',
#   'OOV',
#   '月',
#   'OOV',
#   '回复',
#   'OOV',
#   '大家',
#   '來',
#   '估估',
#   'OOV',
#   '沒錯',
#   '全中',
#   'OOV',
#   '卓越',
#   '网',
#   '待客之道',
#   '拖延',
#   '政策',
#   'OOV',
#   '毫无诚意',
#   'OOV',
#   '出',
#   '问题',
#   '不好',
#   '彩关',
#   '卓越',
#   '网什事',
#   'OOV',
#   '总结',
#   '卓越',
#   '网',
#   '骗到',
#   '订貨',
#   '收',
#   '货后',
#   '不关',
#   '卓越',
#   '网',
#   '事',
#   'OOV',
#   '问題',
#   '事',
#   'OOV',
#   '顧客',
#   '认了',
#   '!',
#   '大家',
#   '來',
#   '评评理',
#   '是否',
#   '卓越',
#   '网应',
#   '該',
#   '大家',
#   '一个个',
#   '合理',
#   '答复',
#   'OOV',
#   '解釋',
#   'OOV',
#   '赔尝',
#   '编辑',
#   '大人',
#   'OOV',
#   '是否',
#   '记得',
#   '曾',
#   '微软',
#   'OOV',
#   '筒体',
#   '商业版',
#   '彩包',
#   '网页',
#   '面于',
#   'OOV',
#   'OOV',
#   '月底',
#   '回复',
#   '问题',
#   'OOV',
#   '当时',
#   '是否',
#   '真的',
#   '安装',
#   '三台',
#   '电脑',
#   '回复',
#   'OOV',
#   '应该',
#   '不会',
#   '老人',
#   '柏金',
#   '失忆',
#   '证',
#   '沒',
#   '请',
#   '不要',
#   '除掉',
#   '问题',
#   '如实',
#   '回复',
#   '当时',
#   '回复',
#   'OOV',
#   '老人',
#   '柏金',
#   '失忆',
#   '证',
#   '不好',
#   '意',
#   '请',
#   '消除',
#   '掉',
#   '问题',
#   '並向',
#   '道歉',
#   '老人',
#   '柏金',
#   '失忆',
#   '证',
#   '病人',
#   '原谅',
#   '!'],
#  ['很', 'OOV', '不错'],
#  ['OOV', '产品价格', '比较', '合理', 'OOV', '期待', 'OOV', '优惠', '幅度', 'OOV'],
#  ['买来', '大伙', '一起', 'OOV', '乐', 'OOV'],
#  ['OOV', '歌词', '显示', 'OOV', '大', '一点', '照片', 'OOV'],
#  ['OOV',
#   '这是',
#   '一套',
#   '值得',
#   '推荐',
#   '音乐欣赏',
#   '讲座',
#   '类型',
#   '音乐',
#   'OOV',
#   '适合',
#   '大人',
#   '理解能力',
#   '孩子',
#   '收听',
#   'OOV',
#   '此前',
#   '已用',
#   'OOV',
#   '发表',
#   '评论',
#   'OOV',
#   '非常',
#   '不错',
#   'OOV',
#   '播音员',
#   '甜美',
#   '声音',
#   '深深',
#   '吸引',
#   '孩子',
#   '大人',
#   'OOV',
#   '女儿',
#   'OOV',
#   '岁',
#   'OOV',
#   '每天',
#   '睡前',
#   '要求',
#   '播放',
#   'OOV',
#   '早晨',
#   '音乐',
#   '唤醒',
#   'OOV',
#   '音乐',
#   '身心愉快',
#   'OOV',
#   '这种',
#   '形式',
#   '音乐',
#   '熏陶',
#   '犹如',
#   '润物细无声',
#   'OOV',
#   '非常感谢',
#   '此套',
#   '音乐',
#   '碟',
#   '制作者',
#   '!',
#   'OOV',
#   'OOV',
#   '朋友',
#   '想',
#   '购买',
#   '胎教',
#   '音乐',
#   'OOV',
#   '建议',
#   '购买',
#   'OOV',
#   '听',
#   '聪明',
#   'OOV',
#   '系列',
#   'OOV',
#   '音乐',
#   '轻快',
#   'OOV',
#   '活泼',
#   'OOV',
#   '不贵',
#   'OOV',
#   '当时',
#   '购买',
#   '这套',
#   'OOV',
#   '张',
#   'OOV',
#   '价格',
#   'OOV',
#   '赠送',
#   'OOV',
#   '碟装',
#   'OOV',
#   '听',
#   '聪明',
#   'OOV',
#   '价值',
#   'OOV',
#   'OOV',
#   'OOV',
#   '经营者',
#   'OOV',
#   'OOV',
#   '强烈推荐',
#   '此套',
#   '作品',
#   'OOV',
#   '建议',
#   'OOV',
#   '不要',
#   '销路',
#   '一味',
#   '提价',
#   '!',
#   '保持',
#   '消费者',
#   '潜在',
#   '消费者',
#   '购买',
#   '热情',
#   '!'],
#  ['很',
#   '不错',
#   '东西',
#   'OOV',
#   '大家',
#   '买',
#   '一定',
#   '认真',
#   'OOV',
#   '坚持下去',
#   'OOV',
#   '效果',
#   '很',
#   'OOV',
#   '听',
#   '新东方',
#   '网络课堂',
#   '对应',
#   '课程',
#   '超值',
#   'OOV',
#   '目前',
#   '建议',
#   '买',
#   '套装',
#   '更',
#   '划算',
#   'OOV',
#   '卓越',
#   '网上',
#   '买',
#   'OOV'],
#  ['好用', 'OOV', '漂亮', '大家', '快来', '买', '!'],
#  ['很', '稀饭', '老狼', '同学'],
#  ['本来',
#   '没太高',
#   '期望',
#   'OOV',
#   '价位',
#   '手机',
#   'OOV',
#   '拿到',
#   '手机',
#   '兴奋',
#   '一阵子',
#   'OOV',
#   '老爸',
#   '一块儿',
#   'OOV',
#   '字大',
#   'OOV',
#   '收音机',
#   'OOV',
#   '放大镜',
#   'OOV',
#   '助听器',
#   '功能',
#   'OOV',
#   '照相',
#   'OOV',
#   '手写',
#   'OOV',
#   '朗读',
#   'OOV',
#   '自动',
#   '答录机',
#   '功能',
#   'OOV',
#   '移动',
#   '秘书',
#   '都',
#   'OOV',
#   '一句',
#   'OOV',
#   '物超所值',
#   '非常适合',
#   '老人',
#   '使用'],
#  ['超', '喜欢', 'OOV', '嘿嘿', '东西', '很'],
#  ['都', '彩图', 'OOV', '介绍', '很', '详细', 'OOV', '很', '实用', '!'],
#  ['买回来',
#   '之后',
#   '放在',
#   '车里',
#   '听',
#   'OOV',
#   '刚刚',
#   '怀孕',
#   'OOV',
#   '胎教',
#   'OOV',
#   '老公',
#   '干吗',
#   '听',
#   '胎教',
#   '音乐',
#   'OOV',
#   '听',
#   '张',
#   'OOV',
#   '希望',
#   '生出',
#   '歌神来'],
#  ['OOV',
#   '数码单反',
#   '套机',
#   'OOV',
#   '网上',
#   '商家',
#   '都',
#   '推出',
#   '价格',
#   'OOV',
#   '以下',
#   '卓越',
#   '降点',
#   '!'],
#  ['没有', 'OOV', '质量', '倒', '没', '!'],
#  ['精彩', '美剧', '做', '详实', '注解', 'OOV', '美剧', 'OOV', '书', '更好'],
#  ['书',
#   '没',
#   '卓越',
#   '买',
#   '学校',
#   '外面',
#   '书店',
#   '小说',
#   '都',
#   'OOV',
#   '折卖',
#   '绝对',
#   '正版',
#   '相比之下',
#   '卓越',
#   '真的',
#   '没有',
#   '竞争力',
#   '快想',
#   '办法',
#   '价格',
#   '下调',
#   '越来越少',
#   '人来',
#   '卓越',
#   '买',
#   '东西'],
#  ['海南出版社',
#   '近期',
#   '准备',
#   '出',
#   'OOV',
#   '秘密',
#   'OOV',
#   'OOV',
#   '侦探',
#   '伽利略',
#   'OOV',
#   '希望',
#   '卓越',
#   '尽快',
#   '引进',
#   '中国',
#   '很多',
#   '东野',
#   '迷',
#   'OOV'],
#  ['尤其', 'OOV', '生于', 'OOV', '年代', 'OOV', '难得', '梳理', '记忆', '好剧'],
#  ['好书', 'OOV', '值得', '推荐', 'OOV'],
#  ['翟老',
#   '教课',
#   '贴近生活',
#   'OOV',
#   '实际',
#   'OOV',
#   '语言',
#   '风趣',
#   'OOV',
#   '很',
#   '意义',
#   'OOV',
#   '个人感觉',
#   '值得',
#   '学习',
#   'OOV'],
#  ['OOV', '电暖气', 'OOV', '拜托', 'OOV', '很', '急'],
#  ['反复', '读的书'],
#  ['很', '!', '很', '!', '很', '!', '很', '喜欢', '!'],
#  ['唐朝',
#   'OOV',
#   '享受',
#   'OOV',
#   '喜欢',
#   '朋友',
#   '自然',
#   '听得出',
#   '喜欢',
#   '味道',
#   'OOV',
#   '耐',
#   '听',
#   '琢磨',
#   '型',
#   '音乐',
#   'OOV',
#   '当然',
#   '出发',
#   '角度',
#   '不同',
#   'OOV',
#   '喜欢',
#   '流行',
#   '文化',
#   '朋友',
#   '算了'],
#  ['比较', '喜欢', '本书'],
#  ['这张', '有没有', 'OOV', '贵', '!'],
#  ['质量', '比较', '耐', '摔', 'OOV'],
#  ['其实', '东西', '都', '很', '饿'],
#  ['今天',
#   '刚看',
#   '完',
#   'OOV',
#   '感觉',
#   '很',
#   'OOV',
#   '配音',
#   '很',
#   '经典',
#   'OOV',
#   '俄语',
#   '原',
#   '声',
#   'OOV',
#   '字幕',
#   '很多',
#   '错误',
#   'OOV',
#   '可能',
#   '加上',
#   '去',
#   '缘故',
#   'OOV'],
#  ['游戏',
#   '曾经',
#   '多次',
#   '感动',
#   'OOV',
#   '电视',
#   '连续剧',
#   '拍得',
#   '挺',
#   'OOV',
#   '演员',
#   '不错',
#   'OOV'],
#  ['永久',
#   '龙珠',
#   'OOV',
#   '永久',
#   '回忆',
#   'OOV',
#   '漫画',
#   '史上',
#   '最好',
#   '一部',
#   'OOV',
#   '童年',
#   '陪伴',
#   '长大',
#   '龙珠',
#   '值得',
#   '珍藏'],
#  ['看到',
#   '笑来',
#   'OOV',
#   '儿童节',
#   '能出',
#   'OOV',
#   'OOV',
#   '搜',
#   '老半天',
#   'OOV',
#   '今天',
#   '豆瓣',
#   '首页',
#   '看到',
#   'OOV',
#   '太高兴',
#   '!',
#   '等不及',
#   'OOV'],
#  ['甲田光雄',
#   '先生',
#   '研究',
#   '断食',
#   '疗法',
#   '专家',
#   'OOV',
#   '刊物',
#   '经常',
#   '报道',
#   '先生',
#   '事迹',
#   'OOV',
#   '宣传',
#   '断食',
#   '疗法',
#   '非凡',
#   '效果',
#   'OOV',
#   '以前',
#   '非常',
#   '了解',
#   'OOV',
#   'OOV',
#   '真正',
#   '亲身',
#   '实践',
#   'OOV',
#   '难免',
#   '有点',
#   '紧张',
#   'OOV',
#   'OOV',
#   '治疗',
#   '苦恼',
#   '腹股沟',
#   '病',
#   'OOV',
#   '横下心来',
#   'OOV',
#   '甲田',
#   '医院',
#   '实行',
#   '断食',
#   '疗法',
#   'OOV',
#   'OOV',
#   '出乎意料',
#   'OOV',
#   '实施',
#   '断食',
#   '疗法',
#   '以前',
#   '想象',
#   '困难',
#   'OOV',
#   '一周',
#   '断食',
#   'OOV',
#   '很',
#   '顺利',
#   '结束',
#   'OOV',
#   '很',
#   '有效',
#   'OOV'],
#  ['完', '本书', 'OOV', '数据库', '设计', '规划', '更深', '认识', 'OOV'],
#  ['里面',
#   '东西',
#   '很全',
#   'OOV',
#   '讲解',
#   '都',
#   '很',
#   '详细',
#   '最初',
#   '学',
#   '日语',
#   '很',
#   'OOV',
#   '送货',
#   '服务',
#   '很',
#   'OOV'],
#  ...]

# %%
# 打印一下看看
print(train_comments_cleaned[0], test_comments_cleaned[0])
print(train_comments_cleaned[1], test_comments_cleaned[1])

# %% [markdown]
# ### 4. 把文本转换成向量
# > 预处理好文本之后，我们就需要把它转换成向量形式，这里我们使用tf-idf的方法。 sklearn自带此功能，直接调用即可。输入就是若干个文本，输出就是每个文本的tf-idf向量。详细的使用说明可以在这里找到： 参考：https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfVectorizer.html  这里需要特别注意的一点是：对于训练数据调用fit_transform, 也就是训练的过程。 但对于测试数据，不能再做训练，而是直接使用已经训练好的object做transform操作。思考一下为什么要这么做？

# %%
# TODO: 利用tf-idf从文本中提取特征,写到数组里面. 
#       参考：https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfVectorizer.html

X_train =  # 训练数据的特征
y_train =  # 训练数据的label
X_test =   # 测试数据的特征
y_test =   # 测试数据的label

print (np.shape(X_train), np.shape(X_test), np.shape(y_train), np.shape(y_test))

# %% [markdown]
# ### 5. 通过交叉验证来训练模型
# > 接下来需要建模了！ 这里我们分别使用逻辑回归，朴素贝叶斯和SVM来训练。针对于每一个方法我们使用交叉验证（gridsearchCV)， 并选出最好的参数组合，然后最后在测试数据上做验证。 这部分已经在第二次作业中讲过。

# %%
from sklearn.linear_model import LogisticRegression
# TODO： 利用逻辑回归来训练模型
#       1. 评估方式： F1-score
#       2. 超参数（hyperparater）的选择利用grid search https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html
#       3. 打印出在测试数据中的最好的结果（precision, recall, f1-score, 需要分别打印出正负样本，以及综合的）
#       请注意：做交叉验证时绝对不能用测试数据。 测试数据只能用来最后的”一次性“检验。
#       逻辑回归的使用方法请参考：http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html
#       对于逻辑回归，经常调整的超参数为： C

# %%
from sklearn.naive_bayes import MultinomialNB
# TODO： 利用朴素贝叶斯来训练模型
#       1. 评估方式： F1-score
#       2. 超参数（hyperparater）的选择利用grid search https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html
#       3. 打印出在测试数据中的最好的结果（precision, recall, f1-score, 需要分别打印出正负样本，以及综合的）
#       请注意：做交叉验证时绝对不能用测试数据。 测试数据只能用来最后的”一次性“检验。
#       朴素贝叶斯的使用方法请参考：https://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.MultinomialNB.html#sklearn.naive_bayes.MultinomialNB
#       对于朴素贝叶斯，一般不太需要超参数的调节。但如果想调参，也可以参考上面的链接，有几个参数是可以调节的。

# %%
from sklearn import svm
# TODO： 利用SVM来训练模型
#       1. 评估方式： F1-score
#       2. 超参数（hyperparater）的选择利用grid search https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html
#       3. 打印出在测试数据中的最好的结果（precision, recall, f1-score, 需要分别打印出正负样本，以及综合的）
#       请注意：做交叉验证时绝对不能用测试数据。 测试数据只能用来最后的”一次性“检验。
#       SVM的使用方法请参考：http://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html
#       对于SVM模型，经常调整的超参数为：C, gamma, kernel。 这里的参数C跟逻辑回归是一样的， gamma和kernel是针对于SVM的参数
#       在这里先不要考虑他们的含义（或者通过官方文档试图理解一下）， 在课程最后的部分会讲到这些内容。

# %% [markdown]
# > 对于超参数的调整，我们经常使用gridsearch，这也是工业界最常用的方法，但它的缺点是需要大量的计算，所以近年来这方面的研究也成为了重点。 其中一个比较经典的成果为Bayesian Optimization（利用贝叶斯的思路去寻找最好的超参数）。Ryan P. Adams主导的Bayesian Optimization利用高斯过程作为后验概率（posteior distribution）来寻找最优解。 https://papers.nips.cc/paper/4522-practical-bayesian-optimization-of-machine-learning-algorithms.pdf 在下面的练习中，我们尝试使用Bayesian Optimization工具来去寻找最优的超参数。参考工具：https://github.com/fmfn/BayesianOptimization  感兴趣的朋友可以去研究一下。

# %% [markdown]
# ### 6. 思考题
# 1. 对于情感分析来说，有一个问题也很重要，比如一个句子里出现了 “我不太兴奋”， “不是很满意”。 在这种情况，因为句子中出现了一些积极的词汇很可能被算法识别成正面的，但由于前面有一个“不”这种关键词，所以否定+肯定=否定，算法中这种情况也需要考虑。另外，否定+否定=肯定， 这种情况也一样。
# 2. 另外一个问题是aspect-based sentiment analysis, 这个指的是做情感分析的时候，我们既想了解情感，也想了解特定的方面。 举个例子： “这部手机的电池性能不错，但摄像不够清晰啊!”, 分析完之后可以得到的结论是： “电池：正面， 摄像：负面”， 也就是针对于一个产品的每一个性能做判定，这种问题我们叫做aspect-based sentiment analysis，也是传统情感分析的延伸。
#
# >``Q``: 对于如上两个问题，有什么解决方案？ 大概列一下能想到的处理方案。 用简介的文字来描述即可。

# %% [markdown]
# // 你的答案在这里.......

# %% [markdown]
# ### 7. 其他领域（仅供参考）
# 跟情感分析类似的领域有叫affective computing, 也就是用来识别情绪(emotion recognition)。但情感和情绪又不太一样，情绪指的是高兴，低落，失落，兴奋这些人的情绪。我们知道真正的人工智能是需要读懂人类的情绪的。而且情绪识别有很多场景，比如服务机器人根据不同的情绪来跟用户交流； 无人驾驶里通过识别用户的情绪（摄像头或者声音或者传感器）来保证安全驾驶； IOT领域里设备也需要读懂我们的情绪； 微博里通过文本读懂每个人发文时的情绪。
#
# 总体来讲，情绪识别跟情感识别所用到的技术是类似的，感兴趣的小伙伴，也可以关注一下这个领域。 如果想发论文，强烈建议选择情绪方面的，不建议选择情感分析，因为问题太老了。情绪分析是近几年才开始受关注的领域。
